# %% [markdown]
# ## Projeto Final - Álgebra Linear e Aplicações (SME0142)
# Projeto confeccionado por Natan Sanches (11795680) e Álvaro José Lopes (10873365).
#
# - **Objetivo e tematização:** A temática utilizada para confecção do projeto foi a de construção de um _pipeline_ dentro do contexto de Processamento de Linguagem Natural. Um texto bruto pôde ser analisado, permitindo um estudo sobre cada palavra individualmente e sua relação com os contextos em sua vizinhança; técnica usualmente chamada de _Word Embedding_. A partir desse estudo, é possível vetorizar palavras e utilizar técnicas de Álgebra Linear para manipulá-las.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
from string import punctuation
from nltk.corpus import stopwords
from collections import Counter
from scipy import sparse
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1. Leitura do texto central
# Neste exemplo, utilizamos a romance Memórias Póstumas de Brás Cubas (clássico de Machado de Assis). O texto foi carregado a partir de um arquivo em disco, criando um _corpus_ (lista) de parágrafos disponíveis para manipulação.

# %%
inputFile = "data/HN_posts_year_to_Sep_26_2016.csv"
language = 'english'
df = pd.read_csv(inputFile)
corpus = df['title']

# %% [markdown]
# ### 2. Pré-processamento do texto

# %% [markdown]
# Como em todo projeto envolvendo processamento de língua natural, é necessário que seja feito um pré-processamento que permite consistência na hora da análise textual. Dentre as técnicas de processamento realizadas, estão:
#
# - Eliminação de conflitos case-sensitive, isto é, transformando todas as letras maiúsculas em minúsculas.
# - Eliminação de caracteres não UTF-8, como uma maneira de preservar a consistência do texto.
# - Eliminação de pontuações e objetos textuais de sinalização, uma vez que estes não serão importantes para a análise.
# - Eliminação de _stop words_, ou palavras de parada (preposições, conjunções, etc), que não possuem contexto isolado.

# %%
punctranslation = str.maketrans(dict.fromkeys(punctuation))
setStopwords = set(stopwords.words(language))

# Realiza a tokenização e tratamento dos parágrafos do texto
def tokenize(corpus: str) -> list:
    corpusTokenized = []
    for paragraph in corpus:
        paragraph = paragraph.lower()                                       # Tratamento de case-sensitive
        paragraph = paragraph.encode('utf8', 'ignore').decode()             # Eliminação de caracteres fora de UTF-8
        paragraph = paragraph.translate(punctranslation)                    # Eliminação de pontuações
        corpusTokenized.append([token for token in paragraph.split()        # Eliminação de stopwords
                                if token not in setStopwords])
    return corpusTokenized
    
corpusTokenized = tokenize(corpus)

# %%
corpusTokenized
# Out:
# [['two', 'days', 'comment', 'want', 'stem', 'cells', 'classified'],
#  ['sqlar', 'sqlite', 'archiver'],
#  ['printed', 'flatscreen', 'television', 'side', 'boxes'],
#  ['algorithmic', 'music'],
#  ['data', 'vault', 'enables', 'nextgen', 'data', 'warehouse', 'data', 'lake'],
#  ['saving', 'hassle', 'shopping'],
#  ['macalifa', 'new', 'opensource', 'music', 'app', 'uwp', 'wont', 'suck'],
#  ['github', 'theweavrsmacalifa', 'music', 'player', 'written', 'uwp'],
#  ['google', 'allo', 'first', 'impression'],
#  ['advanced', 'multimedia', 'linux', 'command', 'line'],
#  ['ask', 'hn', 'tld', 'use', 'local', 'development'],
#  ['muroc', 'maru'],
#  ['companies', 'make', 'products', 'worse'],
#  ['tuning', 'aws', 'sqs', 'queues'],
#  ['promise', 'github'],
#  ['joint', 'rd', 'ups', 'downs'],
#  ['ibm',
#   'announces',
#   'next',
#   'implementation',
#   'apples',
#   'swift',
#   'developer',
#   'language'],
#  ['amazons', 'algorithms', 'dont', 'find', 'best', 'deals'],
#  ['ruffled', 'feathers'],
#  ['veil', 'ignorance', 'design', 'accessbility'],
#  ['ometa', '2008'],
#  ['burning', 'ship', 'fractal'],
#  ['hiroko', 'susie', 'untold', 'stories', 'japanese', 'war', 'brides'],
#  ['robolutionrobocalyptic',
#   'themed',
#   'machine',
#   'learning',
#   'computer',
#   'vision',
#   'tutorials'],
#  ['segas', 'plans', 'world', 'domination', '1993'],
#  ['google', 'car', 'sense', 'money', 'impasse'],
#  ['open', 'web', 'important', 'sea', 'levels', 'rising'],
#  ['forever',
#   '23',
#   'rapid',
#   'rise',
#   'sudden',
#   'disappearance',
#   'velva',
#   'darling'],
#  ['emergency', 'dose', 'epinephrine', 'cost', 'arm', 'leg'],
#  ['abu', 'ashraf', 'masnun', 'introduction', 'django', 'channels'],
#  ['airlines', 'embrace', 'pollution', 'plan', 'could', 'cost', '24b'],
#  ['china', 'completes', 'largest', 'radio', 'telescope', 'world'],
#  ['fastest', 'electric', 'vehicle', 'world'],
#  ['arnold', 'palmer', 'dead', '87'],
#  ['phone', 'makers', 'could', 'cut', 'drivers', 'dont'],
#  ['eniacelectronic', 'numerical', 'integrator', 'computer'],
#  ['cubas', 'diy', 'inventions', '30', 'years', 'isolation', 'video'],
#  ['openmw',
#   'open',
#   'source',
#   'elderscrolls',
#   'iii',
#   'morrowind',
#   'reimplementation'],
#  ['shame', 'microsoft', 'leaving', 'surface', 'pro', 'customers', 'dark'],
#  ['unity', 'google', 'daydream'],
#  ['unitys', 'google', 'daydream', 'vr', 'technical', 'preview', 'available'],
#  ['google', 'internet', 'balloon', 'uses', 'ai', 'stay', 'place', 'weeks'],
#  ['ask', 'hn', 'pass', 'work', 'die'],
#  ['postgresql', 'rds', 'pgstatramdisksize', 'new', 'feature', 'calculations'],
#  ['using', 'gmail', 'like', 'vi'],
#  ['product', 'management', 'job', 'search'],
#  ['wireless', 'signals', 'detect', 'feelings', 'new', 'device'],
#  ['women', 'product'],
#  ['cppcon',
#   '2016',
#   'trip',
#   'report',
#   'thoughts',
#   'favorite',
#   'talks',
#   'sessions'],
#  ['six', 'recipes', 'software', 'managers'],
#  ['munger', 'os', 'live', 'life', 'really', 'works'],
#  ['let', 'facebooks', 'algorithms', 'run', 'life', 'weeks'],
#  ['show', 'hn', 'finding', 'puns', 'computationally'],
#  ['americas', 'lost', 'boys', 'men', 'choose', 'video', 'games', 'work'],
#  ['narrative', 'sexism', 'bangalore', 'startups', 'needs', 'nuance', 'voices'],
#  ['walking', 'tour', 'new', 'yorks', 'massive', 'surveillance', 'network'],
#  ['job',
#   'app',
#   'website',
#   'farms',
#   'social',
#   'network',
#   'links',
#   'illegal',
#   'sketchy',
#   'neither'],
#  ['theory', 'nothing', 'new'],
#  ['show', 'hn', 'simple', 'library', 'complicated', 'animations'],
#  ['mistakenly', 'seeking', 'solitude', '2014'],
#  ['getting', 'know', 'gnu', 'social'],
#  ['microsoft', 'bets', 'future', 'reprogrammable', 'computer', 'chip'],
#  ['free', 'packtpub', 'book', 'r', 'data', 'science'],
#  ['adobe', 'berkeleys', 'new', 'deep', 'learning', 'image', 'editing', 'tool'],
#  ['show', 'hn', 'webgl', 'visualization', 'dna', 'sequences'],
#  ['state', 'theory', 'money'],
#  ['antispoofing', 'bcp', '38', 'tragedy', 'commons', '2014'],
#  ['appropriate', 'uses', 'sqlite'],
#  ['secret', 'uber', 'economy', 'wealth', 'inequality'],
#  ['coming', 'public', 'service', 'loan', 'forgiveness', 'bonanza'],
#  ['show',
#   'hn',
#   'pomodorocentric',
#   'heirarchical',
#   'project',
#   'management',
#   'es6',
#   'modules'],
#  ['next', 'phase', 'agricultural', 'innovation', 'begins'],
#  ['kaltix'],
#  ['gary', 'johnson', 'calls', 'human', 'settlement', 'planets'],
#  ['clean',
#   'cheap',
#   'profitable',
#   'boosting',
#   'real',
#   'estate',
#   'valuations',
#   'innovation'],
#  ['nfl', 'thursdays', 'twitter'],
#  ['ask', 'hn', 'dns', 'problem', 'limited', 'geographic', 'region'],
#  ['review', 'three', 'body', 'problem', 'trilogy'],
#  ['mit',
#   'challenge',
#   '4',
#   'year',
#   'mit',
#   'cs',
#   'curriculum',
#   '1',
#   'year',
#   '2012'],
#  ['lxqt', '011', 'released'],
#  ['ask', 'hn', 'join', 'fund', 'angel'],
#  ['one', 'click', 'buying', 'internetwide'],
#  ['amazon',
#   'fined',
#   'shipping',
#   'lithium',
#   'batteries',
#   'passenger',
#   'planes'],
#  ['pull', 'workers', 'back', 'brink', 'burnout'],
#  ['blue', 'bottle', 'coffee', 'raising', 'another', 'big', 'round', 'funding'],
#  ['snapchat',
#   'releases',
#   'first',
#   'hardware',
#   'product',
#   'spectacle',
#   'destined',
#   'fail'],
#  ['bits', 'pieces', 'lifecycle', 'moral', 'panic'],
#  ['smart', 'pointers', 'move', 'semantics', 'modern', 'c'],
#  ['ungoogled',
#   'chromium',
#   'chromium',
#   'enhanced',
#   'privacy',
#   'control',
#   'transparency'],
#  ['christos',
#   'running',
#   'fence',
#   '40',
#   'years',
#   'later',
#   'photos',
#   'stories',
#   'memories'],
#  ['happens', 'reply', 'spam', 'email'],
#  ['windows',
#   '10',
#   'could',
#   'track',
#   'absolutely',
#   'everything',
#   'ms',
#   'patents',
#   'new',
#   'tracking',
#   'tech'],
#  ['migrating', 'pinterest', 'profiles', 'react'],
#  ['midi', 'enhancements', 'windows', '10'],
#  ['remote', 'disk', 'encryption', 'unlock', 'via', 'ssh'],
#  ['proving', 'grounds', 'geography', 'moba', 'map'],
#  ['learned', 'stroke', '26', 'make', 'time', 'untangle'],
#  ['understanding', 'evdev'],
#  ['simple', 'commodore', '64', 'game', 'c17'],
#  ['chelsea',
#   'mannings',
#   '14',
#   'days',
#   'solitary',
#   'suicide',
#   'attempt',
#   'cruel',
#   'inhuman'],
#  ['still', 'even', 'wrong'],
#  ['horse2016'],
#  ['ask', 'hn', 'someone', 'uses', 'stock', 'trading', 'passive', 'income'],
#  ['fundamental', 'limits', 'machine', 'learning'],
#  ['ecoloblue',
#   '400000',
#   'literday',
#   'atmospheric',
#   'water',
#   'generator',
#   'station'],
#  ['aliens', 'seeking', 'ai'],
#  ['comparing', 'worlds', 'fighter', 'jets'],
#  ['yelps', 'service', 'principles'],
#  ['machine',
#   'ethics',
#   'podcast',
#   'eps',
#   '6',
#   'automated',
#   'cars',
#   'insurance',
#   'industry'],
#  ['solve', 'wooden', 'puzzle', 'python', 'jupyter'],
#  ['dont', 'inspired'],
#  ['marc',
#   'andreessen',
#   'suddenly',
#   'deletes',
#   'tweets',
#   'goes',
#   'twitter',
#   'break'],
#  ['wearable',
#   'tech',
#   'devices',
#   'negative',
#   'effect',
#   'longterm',
#   'weight',
#   'loss',
#   'jama'],
#  ['strong',
#   'growth',
#   'entertainment',
#   'nightlife',
#   'industries',
#   'san',
#   'francisco'],
#  ['possible',
#   'future',
#   'software',
#   'development',
#   'sean',
#   'parent',
#   'video',
#   '2007'],
#  ['idea', 'spotify', 'lifelong', 'learning'],
#  ['10000', 'listings', '30m', 'bookings', 'first', 'year'],
#  ['carver', 'mead', 'research', 'overview'],
#  ['wikilisp'],
#  ['businesses', 'platforms', 'actually', 'disrupting'],
#  ['grand', 'piano', 'vs', 'upright', 'piano'],
#  ['fatherly', 'advice', 'king', '18th', 'century', 'smallpox', 'innoculation'],
#  ['pharo', 'combat', 'complexity', 'software', 'development'],
#  ['isp',
#   'explains',
#   'data',
#   'caps',
#   'fcc',
#   'using',
#   'internet',
#   'like',
#   'eating',
#   'oreos'],
#  ['trick', 'writing', 'better', 'software', 'lies', 'technique'],
#  ['uber',
#   'researching',
#   'new',
#   'verticaltakeoff',
#   'ride',
#   'offering',
#   'flies',
#   'around'],
#  ['college',
#   'students',
#   'take',
#   'wikipedia',
#   'rewrite',
#   'wrongs',
#   'internet',
#   'science'],
#  ['designing', 'producing', '2fa', 'tokens', 'sell', 'amazon', 'college'],
#  ['new',
#   'electric',
#   'car',
#   'designed',
#   '37',
#   'weekly',
#   'subscription',
#   'service'],
#  ['online', 'version', 'famous', 'strategy', 'game', 'nine', 'mens', 'morris'],
#  ['software', 'development', '1', 'hz'],
#  ['make', 'employees', 'feel'],
#  ['motivation', 'behind', 'functional', 'programming', 'simplest', 'word'],
#  ['compaq', 'story'],
#  ['scientists', 'get', 'us', 'step', 'closer', 'graphene', 'implants'],
#  ['uc',
#   'campuses',
#   'scramble',
#   'make',
#   'room',
#   'thousands',
#   'new',
#   'california',
#   'students'],
#  ['respect', 'simon', 'peytonjones'],
#  ['la', 'man', 'built', 'dozens', 'tiny', 'houses', 'homeless'],
#  ['selfdriving', 'vehicles', 'really', 'make', 'cities', 'safer'],
#  ['state', 'javascript', 'frontend', 'frameworks'],
#  ['show', 'hn', 'jumble', 'essays', 'go', 'paulinyourpocket'],
#  ['angularfire2', 'authentication'],
#  ['rootless',
#   'provincialism',
#   'bigger',
#   'problem',
#   'rootless',
#   'cosmopolitanism',
#   '2012'],
#  ['etchosts', 'windows', 'mac'],
#  ['back', 'future', 'squeak', 'practical', 'smalltalk', 'written', '1997'],
#  ['toward', 'practical', 'perceptual', 'video', 'quality', 'metric'],
#  ['wish', 'known', 'yc', 's16'],
#  ['obey', 'testing', 'goat', 'plans', 'second', 'edition'],
#  ['one', 'could', 'help', 'millions'],
#  ['use', 'ssh', 'keys', 'authentication', 'beginners'],
#  ['digital',
#   'signing',
#   '20',
#   'unlimited',
#   'free',
#   'blockchain',
#   'smart',
#   'contracts'],
#  ['node', 'passport', 'postgres'],
#  ['spies', 'keep', 'telling', 'us', 'everything'],
#  ['freebsd', 'issue', '1', 'pdf'],
#  ['proprietary', 'versus', 'open', 'instruction', 'sets', 'pdf'],
#  ['mits', 'flea', 'market', 'specializes', 'rare', 'obscure', 'electronics'],
#  ['analogies', 'fail'],
#  ['apple', 'lettuce', 'remedy', 'garlic', 'breath'],
#  ['finance', 'economy'],
#  ['blockchain',
#   'energy',
#   'p2p',
#   'sharing',
#   'project',
#   'sharecharge',
#   'going',
#   'live',
#   'beta'],
#  ['run', 'rsync', 'remote', 'host', 'sudo'],
#  ['hard', 'scifi'],
#  ['airbnb', 'succeed', 'nigeria'],
#  ['someone', 'testing', 'methods', 'taking', 'entire', 'internet'],
#  ['airbnb', 'helped', 'better', 'product', 'designer'],
#  ['modeling', 'alvin', 'luciers', 'sitting', 'room'],
#  ['product', 'perspective'],
#  ['ask', 'hn', 'hard', 'would', 'make', 'cheap', 'hackable', 'phone'],
#  ['list', 'popular', 'queueing', 'tools', 'solutions'],
#  ['novel', 'solution', 'classic', 'decisiontheory', 'problem'],
#  ['williams', 'xjet'],
#  ['ask', 'hn', 'one', 'deciding', 'factor', 'makes', 'website', 'successful'],
#  ['old',
#   'shipping',
#   'containers',
#   'turned',
#   'small',
#   'apartments',
#   'homeless'],
#  ['correct', 'way', 'validate', 'email', 'adresses'],
#  ['pull', 'requests'],
#  ['aurelia', 'framework', 'updated'],
#  ['hadley', 'wickhams', 'tidy', 'tools', 'manifesto'],
#  ['show',
#   'hn',
#   'learn',
#   'japanese',
#   'vocab',
#   'via',
#   'multiple',
#   'choice',
#   'questions'],
#  ['developers',
#   'dropping',
#   'oculus',
#   'support',
#   'protest',
#   'founders',
#   'politics'],
#  ['data', 'science', 'tool', 'use'],
#  ['skype', 'teams'],
#  ['5', 'keys', 'docker', 'raspberry', 'pi'],
#  ['oreilly',
#   'great',
#   'question',
#   '21st',
#   'century',
#   'whose',
#   'black',
#   'box',
#   'trust'],
#  ['didnt', 'understand', 'junior', 'programmer'],
#  ['overview', 'microsofts', 'bletchley', 'blockchain', 'architecture'],
#  ['europa', 'changed', 'saw', 'solar', 'system'],
#  ['products', 'services', 'google', 'killed'],
#  ['ethereum', 'classic', 'roadmap'],
#  ['github', 'expandinizr'],
#  ['merlin', 'flexible', 'deep', 'learning', 'framework', 'julia'],
#  ['beyond', 'iphone'],
#  ['cog', 'build', 'command', 'pipelines', 'team', 'collaboration', 'tools'],
#  ['calculist', 'multiuseful', 'workflowyexcel', 'hybrid'],
#  ['nasa', 'slow', 'motion', 'sls', 'booster', 'test'],
#  ['9', 'key', 'deep', 'learning', 'papers', 'explained'],
#  ['meet', 'new', 'wall', 'street', 'trader'],
#  ['15',
#   'years',
#   'later',
#   'physics',
#   'highrise',
#   'building',
#   'collapses',
#   'pdf',
#   '21p'],
#  ['cron', 'job', 'tale', 'missing', 'log'],
#  ['authentications', 'last', 'mile'],
#  ['learned', 'luajit'],
#  ['experience', 'esp8266', 'making', 'led', 'strip', 'control', 'shell'],
#  ['vuejs', 'poised', 'become', 'next', 'jquery'],
#  ['show', 'hn', 'turning', 'trello', 'list', 'shared', 'helpdesk'],
#  ['guide', 'disco', 'nightlife', 'truly', 'began'],
#  ['google', 'selfdriving', 'car', 'involved', 'crash', 'mt', 'view', 'today'],
#  ['selinux', 'sandbox', 'escape', 'cxsecuritycom'],
#  ['tim', 'oreilly', 'would', 'alexa'],
#  ['homeowners', 'move', 'choosing', 'affordable', 'states'],
#  ['100m', 'years', 'decorating', 'junk'],
#  ['plants', 'versus', 'photovoltaics', 'better', 'capture', 'solar', 'energy'],
#  ['amazing',
#   'video',
#   'games',
#   'could',
#   'causing',
#   'big',
#   'problem',
#   'america'],
#  ['arent', 'building', 'mobile', 'homes'],
#  ['human', 'rules', 'acquisition'],
#  ['polymer', 'problems', 'solutions'],
#  ['chinas', 'tiangong1', 'space', 'station', 'control', 'crash', 'earth'],
#  ['ask', 'hn', 'world', 'really', 'short', 'software', 'developers'],
#  ['calling', 'sec'],
#  ['forever', 'alone', 'programming', 'fap'],
#  ['paradise',
#   'lost',
#   'copenhagens',
#   'christiania',
#   'commune',
#   'still',
#   'future'],
#  ['inside', 'troubled', 'development', 'star', 'citizen'],
#  ['zuul', '2', 'netflix', 'journey', 'asynchronous', 'nonblocking', 'systems'],
#  ['sleeping', 'sickness', 'hides', 'human', 'kkin'],
#  ['isnt', 'landlord', 'blacklist'],
#  ['applying', 'cnn', 'urban', 'sound', 'classification'],
#  ['tolerate', 'anything', 'except', 'factual', 'inaccuracies'],
#  ['unpicking', 'gordian', 'knot', 'around', 'blockchain', 'patents'],
#  ['judge',
#   'released',
#   '200',
#   'secret',
#   'government',
#   'surveillance',
#   'requests'],
#  ['register', 'vote', 'sending', 'text'],
#  ['intolerant', 'wins', 'dictatorship', 'small', 'minority'],
#  ['meet', 'parents', 'wont', 'let', 'children', 'study', 'literature'],
#  ['time', 'trello', 'standups', 'whiteboard'],
#  ['silicon', 'valley', 'wrong', 'apples', 'airpods'],
#  ['bay', 'area', 'deep', 'learning', 'school', 'day', '2', 'stream'],
#  ['act', 'certificate', 'authority'],
#  ['online', 'radio', 'recording'],
#  ['top', 'successful', 'entrepreneurs', 'world'],
#  ['web', 'designer', 'job'],
#  ['jobs', 'automated', 'say', 'well', 'need', 'guaranteed', 'basic', 'income'],
#  ['hollywood', 'bets', 'big', 'deepwater', 'horizon'],
#  ['decline', 'stack', 'overflow', '2015'],
#  ['bidirectional', 'replication', 'coming', 'postgresql', '96'],
#  ['getting', 'perfect', 'ssl', 'labs', 'score'],
#  ['webgl', 'ocean', 'wave', 'simulation'],
#  ['thing', 'trickledown', 'economics'],
#  ['botnet',
#   'insecure',
#   'cameras',
#   'literally',
#   'caused',
#   'worlds',
#   'largest',
#   'ddos',
#   'attack'],
#  ['object', 'spreadsheets'],
#  ['show',
#   'hn',
#   'markov',
#   'chain',
#   'twitter',
#   'bot',
#   'trained',
#   'comments',
#   'left',
#   'pornhub'],
#  ['worlds', 'best', 'investment', 'next', '12', 'months'],
#  ['archaudit', 'discover', 'vulnerable', 'packages', 'arch', 'linux'],
#  ['chinese', 'government', 'fabricates', 'social', 'media', 'posts', 'pdf'],
#  ['1000yearold',
#   'onion',
#   'garlic',
#   'remedy',
#   'kills',
#   'antibioticresistant',
#   'bugs'],
#  ['finance', 'ruining', 'america'],
#  ['show',
#   'hn',
#   'openemacs',
#   'tiny',
#   'emacs',
#   'clone',
#   '1024',
#   'loc',
#   'c',
#   'based',
#   'kilo',
#   'bsd'],
#  ['blame', 'banks', 'boring', 'chain', 'stores', 'ruining', 'city'],
#  ['immigrants',
#   'arent',
#   'taking',
#   'americans',
#   'jobs',
#   'new',
#   'study',
#   'finds'],
#  ['saxonjs', 'xslt', '30', 'browser'],
#  ['father',
#   'modern',
#   'statistics',
#   'didnt',
#   'believe',
#   'smoking',
#   'caused',
#   'cancer'],
#  ['fast',
#   'postgresql',
#   'client',
#   'library',
#   'python',
#   '3x',
#   'faster',
#   'psycopg2'],
#  ['landmark', 'map', 'reveals', 'genetic', 'wiring', 'cellular', 'life'],
#  ['way', 'likely', 'killed', 'deer', 'sharks', 'bears', 'gators'],
#  ['decentralized', 'world', 'kings'],
#  ['dont', 'brake', 'fonts'],
#  ['elm', 'harmonize', 'f'],
#  ['bay', 'area', 'deep', 'learning', 'school', 'day', '1', 'video'],
#  ['bay', 'area', 'deep', 'learning', 'school', '2016'],
#  ['sonicare',
#   'toothbrush',
#   'teardown',
#   'microcontroller',
#   'h',
#   'bridge',
#   'inductive',
#   'charging'],
#  ['show', 'tell', 'image', 'captioning', 'open', 'sourced', 'tensorflow'],
#  ['ask', 'hn', 'geolocalized', 'public', 'api'],
#  ['android'],
#  ['correcting', 'client', 'time', 'offline', 'sdk'],
#  ['startup', 'world', 'matured', 'time', 'accelerators', 'go'],
#  ['ask', 'hn', 'sell', 'idea'],
#  ['cloudera', 'impala', 'vs', 'redshift', 'cloud', 'dw', 'performance'],
#  ['cities', 'taking', 'another', 'look', 'led', 'lighting', 'ama', 'warning'],
#  ['ask', 'hn', 'doesnt', 'matter', 'p', 'say', 'u', 'long', 'agree'],
#  ['bay',
#   'area',
#   'wages',
#   'soaring',
#   'still',
#   'cant',
#   'keep',
#   'housing',
#   'prices'],
#  ['social',
#   'network',
#   'processes',
#   'isabelle',
#   'coq',
#   'theorem',
#   'proving',
#   'communities',
#   'pdf'],
#  ['stopped', 'reading', 'biographies'],
#  ['tips', 'improving', 'web', 'typography'],
#  ['ultimate', 'guide', 'restaurant', 'management', 'apps'],
#  ['rule', '40', 'healthy', 'saas', 'company', '2015'],
#  ['stanford',
#   'interdisciplinary',
#   'solution',
#   'sound',
#   'recording',
#   'preservation'],
#  ['parkio', 'automating', 'tasks', 'make', '125k', 'per', 'month'],
#  ['rise', 'rise', 'tabletop', 'gaming'],
#  ['asynchronous', 'python'],
#  ['phrase', 'taco', 'tuesday', 'trademarked'],
#  ['good', 'practices', 'using', 'ssh'],
#  ['weekly', 'digest', '5', 'x64dbg'],
#  ['game',
#   'genie',
#   'declassified',
#   'summer',
#   'played',
#   '230',
#   'game',
#   'boy',
#   'games'],
#  ['secret', 'hack', 'get', 'headphone', 'jack', 'iphone', '7', 'video'],
#  ['promise', 'micro', 'framework', '18', 'lines', 'swift', 'code'],
#  ['eliasdb', 'graphbased', 'database'],
#  ['ask', 'hn', 'react', 'charting', 'lib', 'use'],
#  ['five', 'days', 'rosetta', 'head', 'crash', 'landing', 'comet', '67p'],
#  ['create', 'hack', 'style'],
#  ['john', 'carmack', 'plan', 'archive', '2014'],
#  ['swiss', 'endorse', 'new', 'surveillance', 'powers'],
#  ['f35a', 'damaged', 'fire', 'engine', 'start'],
#  ['worlds',
#   'largest',
#   'hedge',
#   'fund',
#   'speaks',
#   'current',
#   'market',
#   'environment',
#   'dalio'],
#  ['show',
#   'hn',
#   'projectokot',
#   'novel',
#   'codefree',
#   'dataapps',
#   'mere',
#   'seconds'],
#  ['macarthur', 'winner', 'wants', 'every', 'child', 'world', 'microscope'],
#  ['googles', 'selfdriving', 'car', 'involved', 'mountain', 'view', 'crash'],
#  ['spells', 'genesis', 'game', 'resets', 'development'],
#  ['lies', 'better', 'hypocrisy', 'special', 'reference', 'current', 'events'],
#  ['spectacles', 'snap', 'inc'],
#  ['swiss', 'secret', 'service', 'agents', 'licence', 'hack', 'computers'],
#  ['ask', 'hn', 'cloud', 'storage', 'solved', 'problem'],
#  ['get', 'meetups', 'conferences'],
#  ['big', 'would', 'social', 'security', 'check', 'wait', 'age', '70'],
#  ['language', 'gophers'],
#  ['hp01', 'cricket', 'hhc', '2016', 'conf'],
#  ['cache', 'management', 'improved'],
#  ['macos', 'sierra', 'accidentally', 'kills', 'app', 'piracy'],
#  ['applying', 'usercentered', 'design', 'errors'],
#  ['blockchain',
#   'github',
#   'load',
#   'balancer',
#   'api',
#   'ai',
#   'widgetjs',
#   'flowci',
#   'weekly',
#   'mashup',
#   '13'],
#  ['ai', 'makes', 'pop', 'music', 'title', 'entirely', 'true'],
#  ['product', 'teams', 'learn', 'london', 'underground', 'fire', '1987'],
#  ['apple',
#   'interested',
#   'buying',
#   'larry',
#   'page',
#   'backed',
#   'electric',
#   'motorcycle',
#   'startup'],
#  ['help', 'decorating', 'room'],
#  ['yann', 'lecun', 'deep', 'learning', 'future', 'ai'],
#  ['scientists', 'confirm', 'universe', 'direction'],
#  ['baking', 'magic', 'software'],
#  ['news', 'navigator', 'monju', 'fastbreeder', 'nuclear', 'reactor', 'work'],
#  ['pure', 'css', 'hyperdrive', 'effect'],
#  ['china', 'begins', 'operating', 'worlds', 'largest', 'radio', 'telescope'],
#  ['five', 'myths', 'middle', 'ages'],
#  ['police',
#   'courts',
#   'misusing',
#   'unreliable',
#   'ip',
#   'address',
#   'information',
#   'pdf'],
#  ['two', 'years', 'spent', 'spamming', 'spammers', 'back'],
#  ['selfdriving',
#   'trucks',
#   'threaten',
#   'one',
#   'americas',
#   'top',
#   'bluecollar',
#   'jobs'],
#  ['b2g', 'os', 'announcements', 'tuesday'],
#  ['ask',
#   'hn',
#   'marketer',
#   'become',
#   'tech',
#   'entrepreneur',
#   'start',
#   'startup'],
#  ['folklore'],
#  ['jason',
#   'turner',
#   'simple',
#   'commodore',
#   '64',
#   'game',
#   'c17',
#   'cppcon',
#   '2016',
#   'video'],
#  ['choosing', 'http', 'status', 'made', 'easy'],
#  ['russians', 'arrested', 'robot', 'rally'],
#  ['metaanalysis',
#   'student',
#   'evaluation',
#   'teachers',
#   'student',
#   'learning',
#   'unrelated'],
#  ['tech',
#   'google',
#   'money',
#   'lurks',
#   'behind',
#   'government',
#   'privacy',
#   'conference'],
#  ['story', 'soundclouds', 'data', 'team'],
#  ['democratization', 'censorship'],
#  ['six', 'securities', 'brings', 'blockchain', 'roadmap', 'switzerland'],
#  ['high', 'hitler', 'nazi', 'drug', 'abuse', 'steered', 'course', 'history'],
#  ['uvloop',
#   'ultra',
#   'fast',
#   'implementation',
#   'asyncio',
#   'event',
#   'loop',
#   'top',
#   'libuv'],
#  ['rarity',
#   'tulsa',
#   'shooting',
#   'female',
#   'officers',
#   'almost',
#   'never',
#   'involved'],
#  ['girls',
#   'life',
#   'vs',
#   'boys',
#   'life',
#   'magazine',
#   'cover',
#   'sparks',
#   'uproar'],
#  ['random', 'generator', 'codedriven', 'art'],
#  ['capcoms',
#   'streetfighter',
#   'rootkit',
#   'capcomsys',
#   'signed',
#   'still',
#   'valid',
#   'symantec',
#   'cert'],
#  ['tvnfo', 'patreon'],
#  ['china', 'begins', 'operating', 'worlds', 'largest', 'radio', 'telescope'],
#  ['race',
#   'condition',
#   'radiation',
#   'therapy',
#   'machine',
#   'killed',
#   '3',
#   'patients'],
#  ['github', 'repository', 'line', 'count'],
#  ['giving', 'refined', 'sugar', 'changed', 'brain'],
#  ['ask', 'hn', 'would', 'government', 'security', 'hacking', 'good'],
#  ['library', 'lobby', 'andreessen', 'horowitz'],
#  ['first', 'year', 'data', 'mars', 'orbiter', 'mission', 'mom', 'released'],
#  ['witnessing', 'highest', 'levels', 'displacement', 'record'],
#  ['ask', 'hn', 'americans', 'really', 'ready', 'give', 'cars'],
#  ['show', 'hn', 'cursor', 'screenshot'],
#  ['krzysztof', 'uraw', 'archives', 'memory', 'libarchive'],
#  ['marc',
#   'andreessen',
#   'takes',
#   'break',
#   'twitter',
#   'deletes',
#   '100k',
#   'tweets'],
#  ['ask', 'hn', 'ever', 'visited', 'examplecom'],
#  ['deeply', 'sorry', 'oculus', 'rift', 'founder', 'palmer', 'luckey'],
#  ['chinas', 'orbiting', 'quantum', 'satellite', 'links', 'ground', 'stations'],
#  ['sharpen', 'pencils', 'time', 'emailiq', 'trivia', 'contest'],
#  ['really', 'muslims'],
#  ['california',
#   'enacts',
#   'law',
#   'requiring',
#   'imdb',
#   'remove',
#   'actor',
#   'ages',
#   'request'],
#  ['protean', 'worlds', 'first', 'reactive', 'gaming', 'keyboard'],
#  ['working', 'fetch', 'api'],
#  ['people', 'losing', 'blissful', 'tingles', 'asmr'],
#  ['china',
#   'begins',
#   'operating',
#   'worlds',
#   'largest',
#   'radio',
#   'telescope',
#   'fast'],
#  ['corned', 'beef', 'sandwich', 'space', 'nearly', 'killed', 'everyone'],
#  ['adhd', 'sold'],
#  ['cant', 'remember', 'wholesale'],
#  ['hipsters',
#   'recompose',
#   'everything',
#   'building',
#   'utility',
#   'library',
#   'react'],
#  ['show', 'hn', 'hangmangame', 'command', 'line', 'knowing', 'words', 'fun'],
#  ['could',
#   'ancient',
#   'remedies',
#   'hold',
#   'answer',
#   'looming',
#   'antibiotics',
#   'crisis'],
#  ['letter', 'berlin', 'startup', 'scene'],
#  ['homing', 'pigeon', 'flocks', 'bad', 'bosses', 'quickly', 'get', 'demoted'],
#  ['twitter',
#   'monitoring',
#   'tool',
#   'helped',
#   'bring',
#   'child',
#   'paedophilia',
#   'site'],
#  ['first', '20', 'years', 'http'],
#  ['impossible', 'colors'],
#  ['free', 'pascal', 'development', 'ubuntu', 'phone'],
#  ['capcoms', 'street', 'fighter', 'v', 'installs', 'hidden', 'rootkit', 'pcs'],
#  ['public',
#   'disclosure',
#   '68',
#   'globalsign',
#   'ssl',
#   'certificates',
#   'issued',
#   'without',
#   'eku',
#   'ku'],
#  ['turn', 'feature', 'tv', 'smart', 'tv', '30'],
#  ['show', 'hn', 'geto', 'mobile', 'local', 'compass'],
#  ['show',
#   'hn',
#   'killer',
#   'narrative',
#   'info',
#   'sec',
#   'nsa',
#   'somewhere',
#   'africa'],
#  ['need', 'suggestions', 'feedbacks', 'comments', 'alivestats'],
#  ['windows', '10', 'undocumented', 'certificate', 'pinning', 'feature'],
#  ['new', 'law', 'forces', 'imdb', 'remove', 'age', 'actors', 'request'],
#  ['great', 'https', 'migration'],
#  ['ask', 'hn', 'best', 'practises', 'using', 'ssh', 'keys'],
#  ['libreroot',
#   'claims',
#   'lead',
#   'dev',
#   'fired',
#   'fsf',
#   'trans',
#   'rms',
#   'disputes'],
#  ['suffocate', 'economy', 'drown', 'massive', 'private', 'debt'],
#  ['amazons', 'algorithm', 'hiding', 'best', 'deal', 'many', 'customers'],
#  ['show',
#   'hn',
#   'spotifyplaylistdownloader',
#   'easily',
#   'download',
#   'spotify',
#   'playlists'],
#  ['chinas', '500m', 'fast', 'radio', 'telescope', 'opens', 'today'],
#  ['loading', 'images', 'progressively', 'using', 'gaussian', 'blur'],
#  ['coding', 'fun', 'technically', 'ethically', 'complex'],
#  ['iron',
#   'maiden',
#   'ed',
#   'force',
#   'one',
#   '2',
#   'engines',
#   'replaced',
#   'chile',
#   'earlier',
#   'year'],
#  ['git', 'paid', 'make', 'code', 'contributions', 'get', 'paid'],
#  ['ionic', 'react', 'native'],
#  ['krebsonsecurity', 'hosted', 'google', 'cloud'],
#  ['built', 'podcast', 'innovators', 'entrepreneurs', 'idealists'],
#  ['surprising', 'stats', 'child', 'carseats'],
#  ['microservices', 'evolutionary', 'architecture'],
#  ['code', 'review'],
#  ['twelve', 'fancy', 'chrome', 'devtools', 'tips'],
#  ['suchflex',
#   'social',
#   'rewards',
#   'live',
#   '5',
#   '1',
#   'invitees',
#   '5',
#   'levels'],
#  ['designing', 'largescale', 'phosphor', 'filtershader'],
#  ['came',
#   'across',
#   'cool',
#   'pixel',
#   'shader',
#   'simulating',
#   'crt',
#   'phosphor',
#   'look'],
#  ['adapted', 'cold', 'shower', 'potential', 'treatment', 'depression', '2008'],
#  ['gnu', 'tools', 'cauldron', '2016', 'videos'],
#  ['education', 'chinas', 'secret', 'weapon', 'tech', 'dominance'],
#  ['api', 'driven', 'workflow', 'management', 'spark', 'azkaban'],
#  ['sick', 'marketdriven', 'world'],
#  ['make', 'app', 'add', 'json'],
#  ['create', 'perfect', 'video', 'tutorials'],
#  ['ask', 'hn', 'know', 'transfer', 'freelancer'],
#  ['introduction',
#   'c4',
#   'traits',
#   'rice',
#   'increase',
#   'photosynthetic',
#   'efficiency'],
#  ['inside', 'former', 'us', 'embassy', 'tehran', 'iran', '2015'],
#  ['lounge',
#   '200',
#   'released',
#   'community',
#   'fork',
#   'shout',
#   'web',
#   'irc',
#   'client'],
#  ['leafie', 'realtime', 'platform', 'open', 'tutoring'],
#  ['show',
#   'hn',
#   'component',
#   'template',
#   'build',
#   'publish',
#   'reusable',
#   'react',
#   'components'],
#  ['amid',
#   'pressure',
#   'charlotte',
#   'police',
#   'release',
#   'videos',
#   'shooting',
#   'keith',
#   'lamont',
#   'scott'],
#  ['story',
#   'allmusic',
#   'internets',
#   'largest',
#   'influential',
#   'music',
#   'database'],
#  ['eqradio', 'emotion', 'recognition', 'using', 'wireless', 'signals'],
#  ['beginners', 'bumpy', 'journey', 'world', 'open', 'source'],
#  ['nasa', 'captured', 'incredible', 'look', 'black', 'hole', 'eating', 'star'],
#  ['coffeescript', '1110', 'released'],
#  ['microsoft',
#   'gives',
#   'details',
#   'controversial',
#   'disk',
#   'encryption',
#   '2015'],
#  ['billion', 'words', 'limits', 'language', 'modeling'],
#  ['interview', 'cal', 'newport', 'author', 'deep', 'work'],
#  ['nodejs', 'important', 'tips', 'production', 'apps'],
#  ['estonia', 'first', 'country', 'europe', 'legalize', 'uber'],
#  ['5', 'reasons', 'successful', 'entrepreneurs', 'mostly', 'iits'],
#  ['san', 'francisco', 'sinking', 'skyscraper', 'deepening', 'dispute'],
#  ['stripe', 'launches', 'beautiful', 'new', 'stripecom'],
#  ['yet', 'another', 'analysis', 'github', 'data', 'google', 'bigquery'],
#  ['software', 'used', 'copy', 'music', '19932003'],
#  ['california',
#   'passes',
#   'law',
#   'requiring',
#   'removal',
#   'actor',
#   'ages',
#   'database',
#   'sites'],
#  ['guiding',
#   'principles',
#   'service',
#   'providerstelcos',
#   'delivering',
#   'cloud',
#   'servicesiot'],
#  ['seat', 'plane'],
#  ['docker', 'image'],
#  ['youve', 'reached', 'monthly', 'tweet', 'limit'],
#  ['python', '4', 'kids', 'python', 'kids', 'python', '3', 'project', '10'],
#  ['case', 'onetomany', 'relationship', 'django', '2013'],
#  ['big', 'problems'],
#  ['app', 'runs', 'chinas', 'economy'],
#  ['rural', 'indian', 'girls', 'chase', 'bigcity', 'dreams'],
#  ['lovehate', 'relationship', 'luajit', '2015'],
#  ['fixing', 'et', 'extraterrestrial', 'atari', '2600'],
#  ['know', 'website', 'good', 'google'],
#  ['4', 'n00b', 'mysql', 'mistakes', 'every', 'programmer', 'makes'],
#  ['bitcoin', 'double', 'spender', 'masses'],
#  ['study',
#   'finds',
#   'young',
#   'men',
#   'playing',
#   'video',
#   'games',
#   'instead',
#   'getting',
#   'jobs'],
#  ['obamas', 'exit', 'interview'],
#  ['graphical',
#   'perception',
#   'graphical',
#   'methods',
#   'analyzing',
#   'scientific',
#   'data',
#   '1985',
#   'pdf'],
#  ['talking', 'c', 'programmers', 'c', 'video'],
#  ['dell',
#   'updates',
#   'xps',
#   '13',
#   'intels',
#   'kaby',
#   'lake',
#   'killer',
#   'wifi',
#   'also',
#   'rose',
#   'gold'],
#  ['white', 'rhino', 'safely', 'roams'],
#  ['phone', 'makers', 'could', 'cut', 'drivers', 'dont'],
#  ['turn', 'iphone', 'notifications', 'four', 'ways', 'get', 'life', 'back'],
#  ['yc', 'application', 'winter', 'batch'],
#  ['cicret', 'bracelet', 'debunk'],
#  ['takes', 'six', 'seconds', 'hear', 'worlds', 'sampled', 'song'],
#  ['trademarking', 'taco', 'tuesday'],
#  ['project',
#   'icestorm',
#   'open',
#   'source',
#   'toolchain',
#   'lattice',
#   'ice40',
#   'fpgas'],
#  ['show', 'hn', 'semile', 'simpler', 'profile', 'diagnose', 'c'],
#  ['yahoo', 'breach', 'hackers', 'may', 'seek', 'intelligence', 'riches'],
#  ['dominance', 'boring', 'languages', 'large', 'scale', 'systems', 'areas'],
#  ['ask', 'hn', 'learn', 'contribute', 'ai', 'singularity'],
#  ['dripcap', 'modern', 'packet', 'analyzer', 'based', 'electron'],
#  ['banning', 'small', 'talk', 'parties'],
#  ['naked', 'shorts', 'cant', 'stay', 'naked', 'forever'],
#  ['dark', 'google', 'shoshana', 'zuboff', '2014'],
#  ['detailed', 'breakdown', 'rendering', 'playdeads', 'inside', 'gdc', '2016'],
#  ['brief', 'guide', 'c', 'template', 'metaprogramming'],
#  ['analysis', 'github', 'data', 'google', 'bigquery'],
#  ['cubr',
#   'rubiks',
#   'cube',
#   'solver',
#   'written',
#   'python',
#   'using',
#   'webcam',
#   'input',
#   '2013'],
#  ['crtc',
#   'implement',
#   'wholesale',
#   'access',
#   'ultra',
#   'fast',
#   'fibre',
#   'networks'],
#  ['begins', 'yahoo', 'sued', 'ultrahack', '500m', 'accounts'],
#  ['study',
#   'explains',
#   'arrest',
#   'moms',
#   'putting',
#   'kids',
#   'nearly',
#   'nonexistent',
#   'danger'],
#  ['pepe', 'stormtroopers'],
#  ['probe',
#   'leaked',
#   'us',
#   'nsa',
#   'hacking',
#   'tools',
#   'examines',
#   'operatives',
#   'mistake'],
#  ['slate', 'star', 'codex', 'ai', 'persuasion', 'experiment'],
#  ['australia',
#   'post',
#   'says',
#   'use',
#   'blockchain',
#   'voting',
#   'expert',
#   'youre',
#   'kidding'],
#  ['snapchat', 'introduces', 'videocatching', 'sunglasses'],
#  ['write', 'chatbot', 'dialogue', 'would', 'make', 'hemingway', 'blush'],
#  ['reorxhttpstat', 'curl', 'statistics', 'made', 'simple'],
#  ['voder', 'bell', 'labs', '1939'],
#  ['phone', 'makers', 'could', 'cut', 'drivers', 'dont'],
#  ['california',
#   'enacts',
#   'law',
#   'requiring',
#   'imdb',
#   'remove',
#   'actor',
#   'ages',
#   'request'],
#  ['final', 'fantasy', 'vii', '1997', 'developer', 'interviews'],
#  ['jailbroke', 'iphone', '7', '24', 'hours'],
#  ['sanaria',
#   'pfspz',
#   'vaccine',
#   'malaria',
#   'receives',
#   'fda',
#   'fast',
#   'track',
#   'designation'],
#  ['incredible', 'journey'],
#  ['journey', 'discover', 'true', 'meaning', 'startup'],
#  ['snapchat', 'changes', 'name', 'snap', 'inc'],
#  ['net', 'standard', 'core', 'tcp', 'services'],
#  ['prof', 'yann', 'lecun', 'deep', 'learning', 'future', 'ai'],
#  ['nasa',
#   'announcing',
#   'surprising',
#   'activity',
#   'jupiters',
#   'moon',
#   'monday'],
#  ['tmobile', 'offering', '200mb', 'per', 'month', 'tablet'],
#  ['japans',
#   'antitrust',
#   'watchdog',
#   'considers',
#   'action',
#   'apple',
#   'carriers'],
#  ['virtues', 'nuclear', 'ignorance'],
#  ['channeling', 'hacker', 'way'],
#  ['floss', 'communitys', 'answers', 'siri', 'ai'],
#  ['freeze',
#   'frame',
#   'film',
#   'uses',
#   'centuryold',
#   'footage',
#   'dug',
#   'within',
#   'yukon',
#   'permafrost'],
#  ['lets', 'build', 'simple', 'interpreter', 'part', '11'],
#  ['googles',
#   'merged',
#   'androidchrome',
#   'os',
#   'andromeda',
#   'may',
#   'teased',
#   'october',
#   '4th'],
#  ['isolated', 'development', 'environment', 'using', 'nix'],
#  ['introverted', 'rude'],
#  ['waste', 'shark', 'drone', 'thats', 'picking', 'garbage', 'oceans'],
#  ['man', 'lit', 'dark', 'web'],
#  ['twoway', 'link', 'docker', 'compose'],
#  ['paris', '1778', 'new', 'force', 'nature', '2014'],
#  ['investigating',
#   'malware',
#   'sample',
#   'sometimes',
#   'fails',
#   'behave',
#   'maliciously'],
#  ['doubts', 'digital', 'ads', 'rise', 'new', 'revelations'],
#  ['booksbyusscalablec', 'scalable', 'c', 'book'],
#  ['elon', 'musk', 'outline', 'plans', 'mars'],
#  ['python', 'c', 'side'],
#  ['gpu', 'programming', 'rust', 'pdf'],
#  ['moley', 'raising', 'money', 'september'],
#  ['whatwg', 'drm', 'web', 'security'],
#  ['invite', 'hn', 'health', 'techies'],
#  ['california',
#   'enacts',
#   'law',
#   'requiring',
#   'imdb',
#   'remove',
#   'actor',
#   'ages',
#   'request'],
#  ['scala',
#   'dsl',
#   'lightweight',
#   'userfriendly',
#   'gpuaccelerated',
#   'matrix',
#   'algebra'],
#  ['show',
#   'hn',
#   'pleenq',
#   'website',
#   'plugin',
#   'create',
#   'object',
#   'links',
#   'within',
#   'images'],
#  ['life', 'know', 'might', 'possible', 'titan'],
#  ['first', 'test', 'driverless', 'minibus', 'paris', 'saturday'],
#  ['unique', 'merger', 'made', 'ewe', 'yew', '2014'],
#  ['rms',
#   'gnu',
#   'refused',
#   'let',
#   'libreboot',
#   'go',
#   'despite',
#   'stating',
#   'intention',
#   'leave'],
#  ['ask', 'hn', 'payment', 'processing', 'group', 'purchases'],
#  ['alraigo', 'incident'],
#  ['trend', 'forecast'],
#  ['linux', '47', 'fully', 'support', 'chromebook', 'pixel', '2015'],
#  ['elixir', 'console', 'json', 'parsing'],
#  ['tls', 'certificates', 'top', 'million', 'sites'],
#  ['vagina', '101', 'pass', 'test'],
#  ['short', 'critique', 'stallmanism'],
#  ['one', 'thing', 'equal', 'thing', '2007', 'pdf'],
#  ['developerworks', 'premium', 'pack', 'cloud', 'services', 'startups'],
#  ['microservices', 'please', 'dont'],
#  ['naval', 'academy', 'name', 'cyber', 'building', 'grace', 'hopper'],
#  ['interviewing', 'developers'],
#  ['gimp', 'inkscape', 'retina', 'macs', 'work'],
#  ['productfounder', 'fit', 'important', 'strategy'],
#  ['ask', 'hn', 'latex', 'editor', 'use'],
#  ['hopes', 'headaches', 'snapchats', 'glasses'],
#  ['tc',
#   'former',
#   'rothenberg',
#   'employees',
#   'allege',
#   'mistreatment',
#   'cash',
#   'management',
#   'problems'],
#  ['golem', 'trustless', 'distributed', 'p2p', 'hosting'],
#  ['concise', 'history', 'neural', 'networks'],
#  ['san', 'francisco', 'getting', 'tiny', 'selfdriving', 'delivery', 'robots'],
#  ['virtual', 'overprotective', 'mom', '2014'],
#  ['show', 'hn', 'share', 'website', 'facebook', 'twitter', 'one', 'click'],
#  ['google',
#   'natural',
#   'language',
#   'api',
#   'kill',
#   'market',
#   'linguistic',
#   'apis',
#   'review'],
#  ['pieter',
#   'hintjens',
#   'building',
#   'open',
#   'source',
#   'communities',
#   'domcode',
#   '2015'],
#  ['googles', 'selfdriving', 'car', 'victim', 'serious', 'crash'],
#  ['eating', 'dogfood'],
#  ['2000', 'custom', 'pc', 'vs', '4000', 'mac', 'pro'],
#  ['jack',
#   'garman',
#   'whose',
#   'judgment',
#   'call',
#   'saved',
#   'moon',
#   'landing',
#   'died'],
#  ['ask', 'hn', 'recommended', 'platform', 'small', 'discussion', 'lists'],
#  ['snapchats', 'spectacles', 'take'],
#  ['tls', 'industry', 'concerns', 'tls', '13'],
#  ['actually', 'moneyball', 'revolution'],
#  ['hackers',
#   'trawl',
#   'user',
#   'data',
#   'hopes',
#   'small',
#   'target',
#   'lead',
#   'big',
#   'one'],
#  ['creationisms', 'reappearance', 'texas', 'state', 'board', 'education'],
#  ['road', 'ahead'],
#  ['code', 'america'],
#  ['ask',
#   'hn',
#   'dont',
#   'online',
#   'stores',
#   'display',
#   'return',
#   'rates',
#   'individual',
#   'products'],
#  ['postgresql', '960', 'release', 'schedule', '9292016'],
#  ['mikey', 'talks', '2fm', 'winning', 'web', 'summit', '2015'],
#  ['huiboard',
#   'five',
#   'andor',
#   'ten',
#   'key',
#   'chorded',
#   'typing',
#   'system',
#   'free',
#   'open',
#   'source'],
#  ['new',
#   'york',
#   'public',
#   'library',
#   'unveils',
#   'cuttingedge',
#   'train',
#   'delivers',
#   'books'],
#  ['rotor', 'browser', 'independent', 'onion', 'routing', 'tor', 'fork'],
#  ['wet', 'prince', 'bel', 'air', 'likely', 'culprits'],
#  ['freenode', 'ddosed'],
#  ['bay', 'area', 'deep', 'learning', 'school', 'day', '2', 'stream'],
#  ['breaking', 'difference', 'economic', 'class', 'social', 'class', 'america'],
#  ['high',
#   'frequency',
#   'trading',
#   'price',
#   'prediction',
#   'using',
#   'lstm',
#   'rnn'],
#  ['google', 'glass', 'dead', 'long', 'live', 'snapchat', 'spectacles'],
#  ['core', 'war', 'ultimate', 'programming', 'game'],
#  ['design', 'analysis', 'quantum', 'cloud'],
#  ['quantum', 'illumination', 'microwave', 'wavelengths'],
#  ['bike',
#   'manufacturer',
#   'sees',
#   'huge',
#   'reduction',
#   'delivery',
#   'damage',
#   'printing',
#   'tv',
#   'box'],
#  ['realtime', 'decentralized', 'offlinefirst', 'graph', 'database', 'engine'],
#  ['internet', 'readmemd', 'would', 'say'],
#  ['show',
#   'hn',
#   'g9js',
#   'automatically',
#   'interactive',
#   'differentiable',
#   'graphics'],
#  ['httpstat', 'like', 'curl', 'v', 'colours'],
#  ['10', 'technical', 'papers', 'every', 'programmer', 'read'],
#  ['snap',
#   'next',
#   'generation',
#   'internet',
#   'portal',
#   'high',
#   'speed',
#   'users',
#   '1999'],
#  ['internet', 'arctic', 'greenlandic', 'relay', 'station'],
#  ['air', 'forces', 'banned', 'briefing', 'ethics', 'nuclear', 'war'],
#  ['ask', 'hn', 'riak', 'viable', 'alternative', 'cassandra'],
#  ['ai', 'need', 'art'],
#  ['psa',
#   'ssh',
#   'publickey',
#   'somewhat',
#   'unexpected',
#   'side',
#   'effect',
#   'preventing',
#   'mitm'],
#  ['african', 'american', 'museum', 'opening', 'dream', 'come', 'true'],
#  ['cryptopals', 'crypto', 'challenges'],
#  ['say', 'big', 'money', 'customers'],
#  ['bad', 'science', 'persists'],
#  ['recurring', 'revenue', 'vs', 'disability', 'insurance'],
#  ['oculus',
#   'rift',
#   'founder',
#   'palmer',
#   'luckey',
#   'spends',
#   'fortune',
#   'backing',
#   'protrump',
#   'shitposts'],
#  ['price', 'connection', 'surveillance', 'capitalism'],
#  ['show',
#   'hn',
#   'automatic',
#   'forecast',
#   'st',
#   'louis',
#   'fred',
#   'economic',
#   'data'],
#  ['google', 'suggestions', 'every', 'letter', 'alphabet'],
#  ['fixed', 'bug', 'today'],
#  ['windows', '10s', 'undocumented', 'certificate', 'pinning', 'feature'],
#  ['better', 'parking', 'garage'],
#  ['ripple',
#   'new',
#   'banking',
#   'group',
#   'first',
#   'blockchainbased',
#   'settlement',
#   'network'],
#  ['project', 'template', 'data', 'science', 'python'],
#  ['good', 'schools', 'bad', 'ones', 'ugly', 'ways', 'rank'],
#  ['new', 'saas', 'platform', 'launched', 'european', 'contech', 'sector'],
#  ['simple', 'python', 'framework', 'buildtrain', 'luis', 'models'],
#  ['startup', 'framework', 'validate', 'idea', 'spend', '1'],
#  ['hpat', 'juliabased', 'framework', 'big', 'data', 'analytics', 'clusters'],
#  ['ask', 'hn', 'tool', 'observe', 'data', 'notify', 'significant', 'changes'],
#  ['detect', 'emotions', 'remotely', 'wireless', 'signals'],
#  ['online', 'appointment', 'scheduling', 'software', 'enterprises'],
#  ['uncolored', 'next', 'generation', 'desktop', 'rich', 'content', 'editor'],
#  ['robot', 'sews', 'could', 'take', 'sweat', 'sweatshops'],
#  ['snapchat', 'changes', 'name', 'snap', 'unveils', 'camera', 'glasses'],
#  ['pdf', 'reflowing', 'mobile'],
#  ['everybody', 'thinks', 'theyre', 'middleclass'],
#  ['led', 'streetlights', 'getting', 'dark', 'reception'],
#  ['postdoc', 'rant', 'long'],
#  ['ai', 'taking', 'control', 'project', 'loon'],
#  ['show', 'hn', 'medical', 'id', 'android', 'app', 'could', 'save', 'life'],
#  ['hacking', 'yahoo', 'means', 'verizon'],
#  ['yahoo', 'toolbar', 'firefox', 'support', 'forum', 'mozilla', 'support'],
#  ['plugzr', 'worlds', 'smartest', 'power', 'outlet'],
#  ['show', 'hn', 'electriq', 'power', 'smarter', 'energy', 'storage'],
#  ['extension',
#   'beta',
#   'contextual',
#   'info',
#   'local',
#   'elections',
#   'interest',
#   'state'],
#  ['show', 'hn', 'worlds', 'first', 'kids', 'art', 'gallery'],
#  ['show',
#   'hn',
#   'hacked',
#   'together',
#   'peace',
#   'day',
#   'love',
#   'button',
#   'seen',
#   'facebook'],
#  ['first',
#   'song',
#   'ever',
#   'written',
#   'artificial',
#   'intelligence',
#   'pretty',
#   'good',
#   'actually'],
#  ['flying', 'saucers', 'true', 'story'],
#  ['sonys', 'lawsuit', 'video', 'game', 'emulation', '2000'],
#  ['programming', 'liberated', 'von', 'neumann', 'style', '1978', 'pdf'],
#  ['compressed', 'hasharray', 'mapped', 'prefixtree'],
#  ['tulip', 'language', 'humans'],
#  ['omni', 'programming', 'language', 'manifest'],
#  ['uber', 'uses', 'microsofts', 'cognitive', 'services', 'verify', 'drivers'],
#  ['expletives',
#   'neurolinguistic',
#   'neurobehavioral',
#   'perspectives',
#   'swearing'],
#  ['ha4', 'concurrent', 'ml', 'hopac'],
#  ['st',
#   'helena',
#   'islanders',
#   'want',
#   'compensation',
#   'unusable',
#   'new',
#   'â£285m',
#   'airport'],
#  ['fast', 'powerful', 'blog', 'system', 'powered', 'laravel', '53'],
#  ['flybrix', 'build', 'drone', 'using', 'lego', 'bricks'],
#  ['stupid', 'cant', 'ignore'],
#  ['biggest', 'solar', 'storm', 'record', 'happened', 'today'],
#  ['ask', 'hn', 'manage', 'server', 'ssh', 'fingerprints'],
#  ['entities', 'arent', 'resources', 'resources', 'arent', 'representations'],
#  ['steal', 'old', 'stuff'],
#  ['gpu', 'accelerated', 'theano', 'keras', 'windows', '10'],
#  ['canonical',
#   'partners',
#   'announce',
#   'nextcloud',
#   'box',
#   'personal',
#   'private',
#   'cloudiot'],
#  ['visual', 'dividers', 'mobile', 'uiux', 'design'],
#  ['physicists', 'bad', 'philosophy', '2011'],
#  ['chicago', 'boys', 'chile', 'economic', 'freedoms', 'awful', 'toll'],
#  ['run', 'unmodified', 'macos', 'binaries', 'linux'],
#  ['maybe', 'careful', 'os', 'x', 'sierra'],
#  ['forth', 'spreadsheet'],
#  ['jonathan',
#   'plackett',
#   'learned',
#   'code',
#   'made',
#   '500k',
#   'first',
#   'face',
#   'swap',
#   'app'],
#  ['silencing', 'krebsonsecurity', 'opens', 'troubling', 'chapter', 'net'],
#  ['design',
#   'better',
#   'business',
#   'new',
#   'tools',
#   'skills',
#   'mindset',
#   'strategy',
#   'innovation'],
#  ['accenture', 'touts', 'need', 'blockchain', 'editing', 'tool'],
#  ['show', 'hn', 'mpw', 'shell'],
#  ['happycubelddecode',
#   'experimental',
#   'laserdisc',
#   'video',
#   'decoder',
#   'raw',
#   'rf',
#   'signal'],
#  ['rovoow', 'new', 'way', 'review', 'compare'],
#  ['politics', 'pockets'],
#  ['australia', 'everyone', 'thinks'],
#  ['ask',
#   'hn',
#   'best',
#   'free',
#   'possible',
#   'wordpress',
#   'themes',
#   'coding',
#   'blogs'],
#  ['density', 'plot', 'prime', 'gaps', 'selfsimilar', 'fractal'],
#  ['hoaxed', '1996'],
#  ['fonts', 'tell', 'us', 'global', 'economics', 'internet'],
#  ['ai', 'doesnt', 'get', 'black', 'twitter'],
#  ['marissa', 'mayer', 'knew', 'yahoo', 'breach', 'probe', 'july'],
#  ['san', 'francisco', 'trying', 'strangle', 'golden', 'goose'],
#  ['happiness'],
#  ['peer', 'review', 'thankless', 'task'],
#  ['kotlin', 'production', 'works', 'whats', 'broken'],
#  ['photos',
#   'prove',
#   'iphone',
#   '7',
#   'plus',
#   'doesnt',
#   'take',
#   'better',
#   'pictures'],
#  ['scania', 'clock'],
#  ['rottweil', 'test', 'tower'],
#  ['dns', 'rebinding', 'hell', 'vulnerability'],
#  ['small',
#   'unmanned',
#   'aircraft',
#   'system',
#   'suas',
#   'registration',
#   'service'],
#  ['automation',
#   'eliminates',
#   'jobs',
#   'tech',
#   'entrepreneurs',
#   'join',
#   'basic',
#   'income',
#   'movement'],
#  ['final', 'journey', 'anders', 'j', 'smedsvik'],
#  ['find', 'perfect', 'react', 'starter', 'project', 'search', 'tool'],
#  ['dont', 'tell', 'aliens', 'stephen', 'hawking', 'says', 'might', 'friendly'],
#  ['stephen', 'hawking', 'warns', 'making', 'contact', 'aliens'],
#  ['wiener', 'sf', 'gov', 'stats', 'sf', 'nightlife', 'entertainment'],
#  ['google', 'deepmind', 'patients', 'trust', 'company', 'data'],
#  ['get', 'sense', 'inevitability', 'founders', 'pitch'],
#  ['first',
#   'ever',
#   'quadriplegic',
#   'treated',
#   'stem',
#   'cells',
#   'regains',
#   'upper',
#   'body',
#   'motor',
#   'control'],
#  ['australia', 'drifting', 'fast', 'gps', 'cant', 'keep'],
#  ['anthony',
#   'bourdain',
#   'talking',
#   'hot',
#   'dogs',
#   'hanoi',
#   'president',
#   'obama'],
#  ['ask',
#   'hn',
#   'best',
#   'apps',
#   'devices',
#   'replacing',
#   'testing',
#   'done',
#   'doctor'],
#  ['digital', 'nomad', 'paradise', 'picked', 'dm'],
#  ['bitcoin', 'wealth', 'distribution'],
#  ['californias', 'propertytax', 'regime', 'worst'],
#  ['hp',
#   'outrages',
#   'printer',
#   'owners',
#   'blocks',
#   'use',
#   'cheap',
#   'ink',
#   'cartridges'],
#  ['damn', 'cool', 'algorithms', 'log', 'structured', 'storage', '2009'],
#  ['humanizing', 'impact', 'soup', '2013'],
#  ['key', 'discovery', 'made', 'simple'],
#  ['science', 'next', 'nothing', 'say', 'moral', 'intuitions'],
#  ['natures', 'libraries', 'fountains', 'biological', 'innovation'],
#  ['french',
#   'companies',
#   'reward',
#   'longterm',
#   'shareholders',
#   'prime',
#   'de',
#   'fidã©litã©'],
#  ['technological', 'singularity'],
#  ['net', 'standard', 'core', 'tcp', 'services'],
#  ['word', 'game', 'based', 'election', 'theme'],
#  ['music', 'confounds', 'machines'],
#  ['four', 'years', 'running', 'server', 'checkin'],
#  ['greatest', 'sales', 'deck', 'ive', 'ever', 'seen'],
#  ['ask', 'hn', 'openai', 'hire', 'using', 'kaggle', 'competition'],
#  ['legislation', 'designed', 'improve', 'fintech', 'innovation', 'us'],
#  ['conscious', 'brain', 'small', 'steps'],
#  ['bay', 'area', 'deep', 'learning', 'school', 'day', '1', 'stream'],
#  ['neural', 'photo', 'editor'],
#  ['renaissance', 'man', 'paul', 'lutus', 'video', '2011'],
#  ['brought', 'https', 'everywhere', 'cloud', 'part', '1'],
#  ['moon', 'exist'],
#  ['root', 'cas', 'used', 'alexa', 'top', '1', 'million', 'sites'],
#  ['cheese', 'rational', '2012'],
#  ['computer', 'scientists', 'close', 'perfect', 'hackproof', 'code'],
#  ['delhi',
#   'high',
#   'court',
#   'ruled',
#   'whatsapp',
#   'delete',
#   'user',
#   'information',
#   'sept',
#   '25th'],
#  ['question', 'everything', 'know', 'fitness'],
#  ['houston', 'regulates', 'land', 'use'],
#  ['ask', 'hn', 'whats', 'best', 'way', 'learn', 'blockchain'],
#  ['cypherpunks',
#   'bitcoin',
#   'hackers',
#   'changing',
#   'world',
#   'tech',
#   'ulterior',
#   'states'],
#  ['90', 'learning', 'isnt', 'cv', 'isnt', 'time', 'changed'],
#  ['google', 'web', 'fonts', 'typographic', 'project'],
#  ['layx', 'layout', 'language'],
#  ['show', 'hn', 'lamp', 'minimal', 'lava', 'lamp', 'web'],
#  ['enable', 'two', 'factor', 'authentication', 'facebook', 'india'],
#  ['diversity', 'fatigue'],
#  ['show',
#   'hn',
#   'instapart',
#   'build',
#   'circuit',
#   'boards',
#   'faster',
#   'instant',
#   'parts'],
#  ['show',
#   'hn',
#   'new',
#   'painless',
#   'couchbase',
#   'java',
#   'sdk',
#   'wrapper',
#   'scala',
#   'futures'],
#  ['configure',
#   'nginx',
#   'free',
#   'lets',
#   'encrypt',
#   'ssl',
#   'certificate',
#   'debianubuntu'],
#  ['zombie', 'moores', 'law', 'shows', 'hardware', 'eating', 'software'],
#  ['secure', 'account', 'recovery', 'made', 'simple'],
#  ['bug', 'hacker', 'news'],
#  ['free', 'lunch', 'theorems'],
#  ['chase', 'made', 'perfect', 'high', 'credit', 'card', 'junkies'],
#  ['comodo', 'gives', 'certificate', 'entirety', 'sb'],
#  ['spacex', 'falcon', '9', 'exploded', 'helium', 'system', 'breach'],
#  ['sync', 'users', 'groups', 'ldap', 'apache', 'ranger'],
#  ['nodejs', 'cluster', 'using', 'raspberry', 'pi', 'zeros'],
#  ['facial',
#   'recognition',
#   'software',
#   'lets',
#   'find',
#   'camgirl',
#   'looks',
#   'like',
#   'crush'],
#  ['open',
#   'source',
#   'android',
#   'game',
#   'using',
#   'liggdx',
#   'framework',
#   'made',
#   'within',
#   'week'],
#  ['dripcap', 'modern', 'packet', 'analyzer', 'based', 'electron'],
#  ['disagreeing', 'jason', 'calacanis', 'platforms'],
#  ['forget', 'virtual', 'assistants', 'asteria', 'wants', 'ai', 'friend'],
#  ['f', 'swearing', 'reveals', 'language'],
#  ['turn', 'android', 'device', 'life', 'saving', 'tool', 'emergency'],
#  ['3d', 'dust', 'mapping', 'panstarrs'],
#  ['read', 'old', 'scroll', 'without', 'opening'],
#  ['isaac', 'asimov', 'asks', 'people', 'get', 'new', 'ideas', '1959'],
#  ['hacker', 'kosovo', 'aided', 'sentenced', '20', 'years', 'us', 'prison'],
#  ['outsmarted'],
#  ['brief', 'history', 'haskell'],
#  ['dwave',
#   'founders',
#   'new',
#   'startup',
#   'combines',
#   'ai',
#   'robots',
#   'monkeys',
#   'exosuits'],
#  ['recap', 'replicability', 'crisis', 'social', 'psychology'],
#  ['lesprit', 'de', 'lescalier', 'staircase', 'wit'],
#  ['semile', 'simpler', 'way', 'profile', 'diagnose', 'c'],
#  ['embracing', 'accelerated', 'mobile', 'pages', 'amp', 'speed', 'profit'],
#  ['decreased', 'brightness', 'increase', 'phones', 'battery', 'life'],
#  ['build', 'wifi', 'walkie', 'talkielike', 'device', 'raspberry', 'pi'],
#  ['dither'],
#  ['youre', 'scientist', 'family'],
#  ['ask',
#   'hn',
#   'youve',
#   'successfully',
#   'outsourced',
#   'software',
#   'dev',
#   'work'],
#  ['serverless',
#   'architecture',
#   'driving',
#   'toward',
#   'autonomous',
#   'operations'],
#  ['harmony',
#   'music',
#   'player',
#   'sleek',
#   'interface',
#   'cloud',
#   'compatibility'],
#  ['coding', 'fun', 'technically', 'ethically', 'complex'],
#  ['spacex', 'released', 'initial', 'results', 'investigation'],
#  ['microsoft',
#   'patents',
#   'way',
#   'copy',
#   'ipc',
#   'search',
#   'engine',
#   'without',
#   'user',
#   'approval'],
#  ['highlights', 'decade', 'hinode', 'solar', 'observatory'],
#  ['quitting', 'facebook', 'made', 'happier', 'productive', 'individual'],
#  ['use', 'google', 'hangouts', 'irc', 'bitlbee'],
#  ['us',
#   'state',
#   'department',
#   'endorses',
#   'impact',
#   'investing',
#   'un',
#   'general',
#   'assembly'],
#  ['cant', 'wait', 'balloon', 'fiesta', 'time', 'albuquerque'],
#  ['2', 'trillion', 'black', 'hole', 'chinas', 'economy'],
#  ['chubby', 'programmer', 'diet', 'part', 'ii', 'feedback'],
#  ['dangers', 'benefits', 'freemium', 'model'],
#  ['apache', 'kudu', '100', 'release'],
#  ['spacex',
#   'large',
#   'breach',
#   'cryogenic',
#   'helium',
#   'system',
#   'caused',
#   'accident'],
#  ['tips', 'startup', 'company'],
#  ['us', 'team', 'claims', 'solar', 'cell', 'efficiency', 'breakthrough'],
#  ['luckey', 'protrump', 'donation', 'actions', 'represent', 'oculus'],
#  ['five',
#   'principles',
#   'extraordinary',
#   'math',
#   'teaching',
#   'dan',
#   'finkel',
#   'tedxrainier'],
#  ['spectacles', 'snap', 'inc'],
#  ['going'],
#  ['accessible', 'svgs', 'high', 'contrast', 'mode'],
#  ['using', 'system', 'fonts', 'websites', 'svg'],
#  ['xbrowsersync',
#   'secure',
#   'anonymous',
#   'free',
#   'browser',
#   'sync',
#   'across',
#   'devices'],
#  ['hackers', 'house', 'iot', 'devices', 'may', 'already', 'joined', 'botnet'],
#  ['passages', 'biases', 'reliability', 'oral', 'histories'],
#  ['video', 'games', 'weakening', 'workforce'],
#  ['engineers', 'create', 'roomtemperature', 'multiferroic', 'material'],
#  ['pirate', 'coelho', '2008'],
#  ['haitians', 'perilous', 'journey', 'find', 'door', 'us', 'abruptly', 'shut'],
#  ['need', 'feel', 'loved'],
#  ['tabswitcher', 'increase', 'productivity', 'google', 'chrome'],
#  ['seeing', 'earth', 'space', 'naoko', 'yamazaki', 'tedxhaneda'],
#  ['capcoms',
#   'signed',
#   'windows',
#   'driver',
#   'allows',
#   'arbitrary',
#   'kernellevel',
#   'code',
#   'execution'],
#  ['googles', 'mobile', 'website', 'speed', 'testing', 'tool'],
#  ['experts',
#   'decry',
#   'solitary',
#   'confinement',
#   'chelsea',
#   'manning',
#   'suicide',
#   'attempt'],
#  ['summer', 'fireworks', 'rosetta'],
#  ['aliens', 'looking', 'ai'],
#  ['making',
#   'advances',
#   'pharmaceutical',
#   'packing',
#   'benefitting',
#   'technology'],
#  ['anyone',
#   'interested',
#   'selling',
#   'old',
#   'ios',
#   'android',
#   'web',
#   'applications'],
#  ['sharkwheel'],
#  ['simile', 'widgets'],
#  ['another',
#   'dimension',
#   '3d',
#   'visualisation',
#   'redefines',
#   'milky',
#   'way',
#   'local',
#   'architecture',
#   '2015'],
#  ['real', 'life', 'infographic', '100', 'objects', 'integrated', 'iphone'],
#  ['moving', 'beyond', 'flash', 'yahoo', 'html5', 'video', 'player'],
#  ['3q',
#   'berhardt',
#   'trout',
#   'spurring',
#   'innovation',
#   'drug',
#   'manufacturing'],
#  ['esa', 'star', 'mapper'],
#  ['g2',
#   'crowd',
#   'crowdsourced',
#   'software',
#   'reviews',
#   'lead',
#   'enterprise',
#   'insights'],
#  ['whatsapp',
#   'may',
#   'incorporate',
#   'passcode',
#   'recovery',
#   'email',
#   'options'],
#  ['alex', 'tapscott', 'blockchain', 'revolution', 'talks', 'google'],
#  ['satellites',
#   'help',
#   'link',
#   'texas',
#   'earthquakes',
#   'wastewater',
#   'injection'],
#  ['postgresql', 'streaming', 'replication'],
#  ['stop', 'madness', 'avoid', 'bad', 'seo', 'advice'],
#  ['pharma',
#   'used',
#   'government',
#   'help',
#   'leverage',
#   'huge',
#   'price',
#   'increases'],
#  ['high', 'availability', 'elixir', 'erlang'],
#  ['street', 'fighter', 'v', 'installs', 'hidden', 'rootkit', 'pcs'],
#  ['microsoft',
#   'said',
#   'readying',
#   'slack',
#   'competitor',
#   'november',
#   'beta',
#   'test'],
#  ['freedom', 'associate'],
#  ['sulong', 'dynamic', 'runtime', 'llvmbased', 'languages'],
#  ['official', 'going', 'mars'],
#  ['want', 'hero'],
#  ['government', 'severs', 'ties', 'forprofit', 'colleges', 'accreditor'],
#  ['cosmic', 'latte'],
#  ['show', 'hn', 'five', 'c', 'singleheader', 'libraries', 'chobolabs'],
#  ['show',
#   'hn',
#   'wikimentions',
#   'discover',
#   'bookspeoplevideos',
#   'mentioned',
#   'great',
#   'people'],
#  ['show', 'hn', 'pjon', 'website'],
#  ['ntsb',
#   'uncontained',
#   'lpt',
#   's3',
#   'disk',
#   'failure',
#   'events',
#   'ge',
#   'cf6',
#   '2010',
#   'pdf'],
#  ['beginning', 'machine', 'learning', 'keras', 'tensorflow'],
#  ['targeted', 'attack', 'gnupgpgp'],
#  ['osso', 'modern', 'standard', 'eventoriented', 'data'],
#  ['recovering', 'deleted', 'draft', 'gmail', '2015'],
#  ['weekly',
#   'python',
#   'stackoverflow',
#   'report',
#   'xxxviii',
#   'stackoverflow',
#   'python',
#   'report'],
#  ['brian',
#   'okken',
#   '22',
#   'converting',
#   'manual',
#   'tests',
#   'automated',
#   'tests'],
#  ['freebsd', '110', 'amd64', 'binaries'],
#  ['paper', 'planes'],
#  ['goldman',
#   'sachs',
#   'axing',
#   'nearly',
#   '30',
#   'percent',
#   'asia',
#   'investment',
#   'banking',
#   'jobs'],
#  ['nsas',
#   'failure',
#   'report',
#   'shadow',
#   'broker',
#   'vulns',
#   'underscores',
#   'need',
#   'oversight'],
#  ['mobile', 'app', 'design', 'tips', 'boost', 'app', 'discoverability'],
#  ['introduction',
#   'stock',
#   'market',
#   'data',
#   'analysis',
#   'python',
#   'part',
#   '1'],
#  ['openaps', 'open', 'artificial', 'pancreas', 'system'],
#  ['aidriven', 'robotics', 'one', 'human', 'worker', 'work', 'four'],
#  ['cannibals', 'every', '16thcentury', 'map', 'new', 'world', '2015'],
#  ['given', 'artificial', 'intelligence', 'much', 'power', 'soon'],
#  ['single', 'photon', 'carries', '10', 'bits', 'information'],
#  ['quantum',
#   'computing',
#   'cripple',
#   'encryption',
#   'methods',
#   'within',
#   'decade'],
#  ['dicaprios', 'phenomenon'],
#  ['headless', 'cms', 'reactjs'],
#  ['airbnb', 'host', 'guarantee', 'total', 'fraud'],
#  ['ask', 'hn', 'opensource', 'alternatives', 'tcpdump'],
#  ['one', 'best', 'investments', 'made', 'developer', 'standing', 'desk'],
#  ['nasa', 'reveal', 'surprising', 'activity', 'jupiters', 'moon', 'europa'],
#  ['neuroscientists', 'need', 'study', 'crow'],
#  ['terry', 'taos', 'notes', 'complex', 'differentiation'],
#  ['hackmud', 'mmo', 'hacking', 'sim', '90s', 'vibe'],
#  ['beginners', 'guide', 'joining', 'hackathon', 'nontechie'],
#  ['algorithmic', 'beauty', 'plants', 'pdf'],
#  ['stop', 'relying', 'gui', 'cli', 'rocks'],
#  ['mechanical', 'turk', 'allows', 'usbased', 'requesters'],
#  ['snapchat', 'company', 'rebrands', 'snap', 'inc'],
#  ['ircv3'],
#  ['new',
#   'iphones',
#   'features',
#   'include',
#   'oppression',
#   'inequality',
#   'vast',
#   'profit'],
#  ['investors', 'support', 'tesla', 'solarcity', 'merger'],
#  ['five',
#   'botswanan',
#   'lionesses',
#   'grow',
#   'manes',
#   'start',
#   'acting',
#   'like',
#   'males'],
#  ['ask', 'hn', 'think', 'android', 'app'],
#  ['introduction', 'galois', 'theory'],
#  ['perl', '6', 'intro'],
#  ['ask', 'hn', 'happened', 'myra'],
#  ['ask', 'hn', 'learn', 'team'],
#  ['protonmail', 'security', 'advisory', 'regarding', 'yahoo', 'hack'],
#  ['yabb', 'messenger', 'free', 'calls', 'free', 'text'],
#  ['ask', 'hn', 'put', 'restrictive', 'ip', 'contracts'],
#  ['ssl', 'certificate', 'supportprofileapplecom', 'expired'],
#  ['cloud', '9', 'online', 'ide', 'hacked', 'c9io'],
#  ['building', 'microservices', 'spring', 'boot'],
#  ['america', 'became', 'global', 'cheese', 'power'],
#  ['forth', 'dimensions'],
#  ['hillarys', 'campaign', 'almost', 'certainly', 'using', 'big', 'data'],
#  ['crowdsourced', 'startup', 'investment'],
#  ['1', 'unread', 'topsmnews', 'topsmnews', 'plurk', 'plurk'],
#  ['americans', 'ages', 'spurning', 'drivers', 'licenses'],
#  ['dripcap', 'packet', 'analyzer'],
#  ['cheatagram', 'story', 'cheaters', 'instagram'],
#  ['tardigrades', 'became', 'immune', 'radiation'],
#  ['microsoft', 'unveiled', '37', 'nokia', 'phone'],
#  ['japan', 'cant', 'nbc', 'documentary', '1980'],
#  ['show',
#   'hn',
#   'manipulist',
#   'new',
#   'textlist',
#   'manipulation',
#   'time',
#   'saver'],
#  ['gene', 'editing', 'cure', 'cancer'],
#  ['training', 'corpus', 'problem'],
#  ['bussard', 'ramjet'],
#  ['youtube', 'changes', 'youtube', 'heroes', 'video', 'stealthily'],
#  ['cqrlog', 'advanced', 'ham', 'radio', 'logger'],
#  ['chronolapse',
#   'easily',
#   'create',
#   'publish',
#   'owntimelapse',
#   'stopmotion',
#   'videos'],
#  ['systemtap',
#   'simplify',
#   'gathering',
#   'information',
#   'running',
#   'linux',
#   'system'],
#  ['go', 'green', 'go', 'red', 'go', 'japan'],
#  ['change', 'world', 'sleep'],
#  ['snapchat',
#   'unveils',
#   '130',
#   'connected',
#   'sunglasses',
#   'rebrands',
#   'snap',
#   'inc'],
#  ['apache',
#   'spark',
#   'streaming',
#   'spark',
#   'streaming',
#   'analytics',
#   'real',
#   'time',
#   'analytics'],
#  ['update', 'android', 'resssource', 'code', 'without', 'reinstalling', 'apk'],
#  ['tiny', 'c', 'compiler'],
#  ['untold', 'stories', 'japanese', 'war', 'brides'],
#  ['matthew', 'garrett', 'explains', 'increase', 'security', 'boot', 'time'],
#  ['big', 'data', 'revolutionizing', 'political', 'campaigning'],
#  ['gcpp',
#   'experimental',
#   'deferred',
#   'unordered',
#   'destruction',
#   'library',
#   'c'],
#  ['facebooks', 'recent', 'changes', 'bad', 'lowvision', 'users'],
#  ['insanity', 'brilliance', 'ethereums', 'developer', 'conference'],
#  ['gammaray',
#   'examining',
#   'manipulate',
#   'internals',
#   'qt',
#   'applications',
#   'runtime'],
#  ['difference', 'string', 'string', 'c'],
#  ['robert', 'gottlieb', 'art', 'editing', '1'],
#  ['pushing', 'database', 'scalability', 'gpus'],
#  ['fbi', 'files', 'nikola', 'tesla'],
#  ['quartz', 'used', 'military', 'radio', 'communication'],
#  ['connectivity', 'issues', 'dallas'],
#  ['iran', 'building', 'censorshipfriendly', 'domestic', 'internet'],
#  ['bohr', 'bohm', 'language', '2013'],
#  ['disagreeing', 'jason', 'calacanis', 'platforms'],
#  ['code', 'took', 'america', 'moon', 'published', 'github'],
#  ['hosting',
#   'parse',
#   'server',
#   'background',
#   'jobs',
#   'webhooks',
#   'livequeries'],
#  ['cassini', 'grand', 'finale', 'ahead', 'mondays', 'press', 'conferece'],
#  ['bogdanov', 'affair'],
#  ['put', 'original', '1979', 'mit'],
#  ['bay', 'area', 'deeplearning', 'school'],
#  ['rise', 'china', 'growing', 'demand', 'consensusbased', 'security'],
#  ['fsf', 'hiring', 'senior', 'gnulinux', 'systems', 'administrator'],
#  ['many', 'die', 'medical', 'mistakes', 'us', 'hospitals', '2013'],
#  ['shahrukh', 'khan', 'bot'],
#  ['single', 'photon', 'carries', '10', 'bits', 'information'],
#  ['zombie', 'moores', 'law', 'shows', 'hardware', 'eating', 'software'],
#  ['flipping', 'react', 'accordions', 'get', '60fps'],
#  ['growing', 'problem', 'bots', 'fight', 'online'],
#  ['show', 'hn', 'elasticsearch', 'geo', 'polygon', 'drawing', 'debugging'],
#  ['test', 'skills', 'vs', 'friends', 'coworkers', 'companies'],
#  ['ttip',
#   'trade',
#   'deal',
#   'could',
#   'relaunched',
#   'different',
#   'name',
#   'say',
#   'eu',
#   'ministers'],
#  ['making', 'twitter', 'bot', 'using', 'google', 'spreadsheets'],
#  ['tiny',
#   'implant',
#   'could',
#   'connect',
#   'humans',
#   'machines',
#   'like',
#   'never'],
#  ['largest',
#   'ddos',
#   'attack',
#   'ever',
#   'delivered',
#   'botnet',
#   'iot',
#   'devices'],
#  ['chromium', 'longer', 'supported', 'chromecast'],
#  ['slate',
#   '20',
#   'years',
#   'old',
#   'reflects',
#   'value',
#   'taking',
#   'long',
#   'view'],
#  ['p2p', 'web', 'powered', 'torrents', 'blockchain'],
#  ['ripple', 'effects', 'api', 'growth', 'technical', 'writers'],
#  ['gaussian', 'processes', 'dummies'],
#  ['use', 'javascript', 'framework'],
#  ['amsi', 'windows', '10', 'plans', 'stop', 'scriptbased', 'attacks', 'well'],
#  ['ask', 'hn', 'bad', 'experiences', 'going', 'yc', 'program'],
#  ['maybe', 'careful', 'os', 'x', 'sierra'],
#  ['multiclick', 'analysis', '62000', 'people', 'click', 'wherever', 'want'],
#  ['front', 'page', 'hacker', 'news'],
#  ['endianness'],
#  ['metaclasses', 'abc'],
#  ['americas', 'monopoly', 'problem'],
#  ['joy', 'refactoring', 'strong', 'static', 'types'],
#  ['taiwan', 'google', 'images', 'disputed', 'island', 'clear'],
#  ['iran',
#   'oil',
#   'industry',
#   'fires',
#   'blasts',
#   'raise',
#   'suspicions',
#   'hacking'],
#  ['nokia', 'demonstrate', 'technique', 'terabitspeed', 'data', 'opticalfiber'],
#  ['verge', 'editor', 'secretly', 'worked', 'apple'],
#  ['tips', 'ensuring', 'get', 'sweet', 'deal', 'cloud', 'contract'],
#  ['predictions', 'speed', 'data'],
#  ['gitlab', '8121', 'released'],
#  ['advanced', 'aws', 'reserved', 'instance', 'reporter'],
#  ['building', 'insights', 'engine'],
#  ['create', 'os', 'kernel', 'scratch'],
#  ['snapchat', 'releases', 'first', 'hardware', 'product', 'spectacles'],
#  ['cosignio', 'open', 'secure', 'identity', 'platform'],
#  ['investors', 'support', 'tesla', 'solarcity', 'merger'],
#  ['snapchat', 'releases', 'first', 'hardware', 'product', 'spectacles'],
#  ['snapchat', 'releases', 'first', 'hardware', 'product', 'spectacles'],
#  ['nsas',
#   'failure',
#   'report',
#   'leaked',
#   'vulnerabilities',
#   'underscores',
#   'need',
#   'oversight'],
#  ['automated', 'image', 'captioning', 'using', 'machine', 'learning'],
#  ['czar', 'pino'],
#  ['thousands',
#   'verizon',
#   'customers',
#   'report',
#   'unexplained',
#   'surge',
#   'data',
#   'usage'],
#  ['global', 'spacebased', 'adsb', 'flight', 'tracking'],
#  ['itch',
#   'relief',
#   'mirror',
#   'scratching',
#   'psychophysical',
#   'study',
#   'ig',
#   'nobel',
#   'winner'],
#  ['talk', 'python', '77', '20', 'python', 'libraries', 'arent', 'using'],
#  ['javascript', 'conditional', 'comments', 'ie'],
#  ['gp', 'ycr', 'harc'],
#  ['oh', 'snap', 'looks', 'like', 'snapchat', 'could', 'rebranding'],
#  ['generate', 'music', 'tensorflow'],
#  ['violence', 'police', 'officers', 'trigger', 'increased', 'discrimination'],
#  ['ddos', 'attacks', 'decentralized', 'internet'],
#  ['icheckmusic', 'complete', 'popular', 'music', 'lists'],
#  ['spotify', 'art', 'playlist'],
#  ['bay', 'area', 'deep', 'learning', 'school', 'live', 'streamed', 'weekend'],
#  ['treatment',
#   'snowden',
#   'proves',
#   'us',
#   'govt',
#   'doesnt',
#   'care',
#   'first',
#   'amendment'],
#  ['digabios',
#   'linuxbased',
#   'liveoperating',
#   'system',
#   'matriculation',
#   'exams'],
#  ['scientists', 'get', 'us', 'step', 'closer', 'graphene', 'implants'],
#  ['lets', 'put', 'end', 'hotel', 'price', 'gouging'],
#  ['game', 'engine', 'containers', 'handlemap'],
#  ['uber',
#   'drivers',
#   'protest',
#   'west',
#   'zone',
#   'colleagues',
#   'death',
#   'brazil'],
#  ['predicting', 'vote', 'pledges', 'via', 'social', 'alignment'],
#  ['twitters',
#   'potential',
#   'new',
#   'owner',
#   'hope',
#   'google',
#   'something',
#   'spam'],
#  ['stepbystep', 'guide', 'hugo', 'netlify', 'netlify'],
#  ['show', 'hn', 'lamp', 'soothing', 'lava', 'lamp'],
#  ['programmer', '1967', 'pdf'],
#  ...]

# %% [markdown]
# ### 3. Contagem de unigramas do texto

# %% [markdown]
# Realiza, para cada parágrafo, a contagem de frequência de cada _token_ do texto.

# %%
unigrams = Counter()
for paragraph in corpusTokenized:
    for token in paragraph:
        unigrams[token] += 1

# Mapeamento de acesso (Token <-> Índice representativo)
token2index = {token: index for index, token in enumerate(unigrams.keys())}
index2token = {index: token for token, index in token2index.items()}

# %%
len(token2index)
# Out:
# 99366

# %% [markdown]
# ### 4. Contagem de bigramas do texto

# %% [markdown]
# Realiza, para cada parágrafo, a contagem dos bigramas presentes. Um bigrama representa a ocorrência de um par palavra-contexto, de maneira com que o contexto esteja dentro da janela de contexto. Nesse caso, o _range_ da janela de contexto foi de três palavras (para frente e para trás).

# %%
# Contador de bigramas, considerando uma determinada janela de contexto (nesse caso, 'gap'
# palavras antes e 'gap' palavras depois)
skipgrams = Counter()
gap = 5

for paragraph in corpusTokenized:
    tokens = [token2index[tok] for tok in paragraph]
    
    # Para cada palavra no parágrafo, realiza a análise dos contextos da vizinhança
    for indexWord, word in enumerate(paragraph):
        indexContextMin = max(0, indexWord - gap)
        indexContextMax = min(len(paragraph)-1, indexWord + gap)

        # Para cada contexto da vizinhança, crie um bigrama com a palavra central
        indexContexts = [index for index in range(indexContextMin, indexContextMax + 1) if index != indexWord]
        for indexContext in indexContexts:
            skipgram = (tokens[indexWord], tokens[indexContext])
            skipgrams[skipgram] += 1

# Exibição dos 10 bigramas mais comuns presentes no texto, considerando a janela de contexto estipulada
mostCommon = [(index2token[skipgram[0][0]], index2token[skipgram[0][1]], skipgram[1]) 
               for skipgram in skipgrams.most_common(10)]
mostCommon
# Out:
# [('show', 'hn', 10312),
#  ('hn', 'show', 10312),
#  ('ask', 'hn', 9347),
#  ('hn', 'ask', 9347),
#  ('open', 'source', 2058),
#  ('source', 'open', 2058),
#  ('machine', 'learning', 1227),
#  ('learning', 'machine', 1227),
#  ('silicon', 'valley', 1070),
#  ('valley', 'silicon', 1070)]

# %%
minCount = (1 / 1100) * len(corpus)
maxCount = (1 / 55) * len(corpus)
print(minCount, maxCount)
# Out:
# 266.4718181818182 5329.436363636363

# %%
# Removendo tokens muito frequentes e muito raros
updatedtoken2index = token2index.copy()
updatedindex2token = index2token.copy()

print('%d antes' % len(unigrams))
minCount = (1 / 1000) * len(corpus)
maxCount = (1 / 50) * len(corpus)
for token in list(unigrams.keys()):
    if unigrams[token] < minCount or unigrams[token] > maxCount:
        del unigrams[token]
        index = token2index[token]
        del updatedtoken2index[token]
        del updatedindex2token[index]
print('%d depois' % len(unigrams))
print('Unigramas mais comuns', unigrams.most_common()[:25])
# Out:
# 99366 antes
# 972 depois
# Unigramas mais comuns [('google', 5532), ('app', 5124), ('using', 4613), ('us', 4189), ('web', 4134), ('startup', 3849), ('open', 3828), ('first', 3730), ('code', 3705), ('apple', 3695), ('pdf', 3659), ('software', 3558), ('video', 3462), ('tech', 3410), ('free', 3180), ('2016', 3108), ('use', 3100), ('learning', 3092), ('time', 2934), ('facebook', 2853), ('go', 2836), ('get', 2766), ('one', 2764), ('make', 2751), ('world', 2712)]

# %%
# Removendo os bigramas que não existem mais por conta da remoção de alguns unigramas
print(f'{len(skipgrams)} antes')
for word, context in list(skipgrams.keys()):
    if index2token[word] not in unigrams or index2token[context] not in unigrams:
        del skipgrams[(word, context)]
print(f'{len(skipgrams)} depois')
# Out:
# 4737990 antes
# 460155 depois

# %%
# Mapeamento de acesso (Token <-> Índice representativo)
token2index, index2token = updatedtoken2index.copy(), updatedindex2token.copy()

# %% [markdown]
# ### 5. Criação da matriz de frequência termo-a-termo

# %% [markdown]
# Criação da matriz que relaciona dois _tokens_ (um bigrama) ao seu devido número de ocorrências.

# %%
# Mapeamento das entradas da matriz esparça de frequência entre os bigramas do texto
rowsMatrix = []
columnsMatrix = []
dataMatrix = []

for (token1, token2), skipgramCount in skipgrams.items():
    rowsMatrix.append(token1)
    columnsMatrix.append(token2)
    dataMatrix.append(skipgramCount)

wwMatrix = sparse.csr_matrix((dataMatrix, (rowsMatrix, columnsMatrix)))
wwMatrix
# Out:
# <10503x10503 sparse matrix of type '<class 'numpy.int64'>'
# 	with 460155 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ### 6. Criação da matriz PPMI

# %% [markdown]
# O PMI (Pointwise Mutual Information) é uma métrica que relaciona a probabilidade de ocorrência de uma palavra em conjunto com certo contexto, quando comparada à ocorrência de ambos isolados. Dessa forma, para uma palavra $w$ relacionada a um contexto $c$, o PMI dentre elas é dado pela relação
#
# $$pmi(w, c) = \log{\left(\dfrac{P(w, c)}{P(w)P(c)}\right)}$$
#
# onde $P(w, c)$ representa a probabilidade de ocorrência de determinada palavra em determinado contexto, $P(w)$ representa a probabilidade de ocorrência de determinada palavra no texto e $P(c)$ representa a probabilidade de ocorrência de determinado contexto no texto. Munidos dessa informação, podemos eliminar a possibilidade de $pmi(w, c)$ assumir valores negativos utilizando sua variação denominada de PPMI (Positive Pointwise Mutual Information), dada por
#
# $$ppmi(w,c) = \textrm{max}(0,\ pmi(w, c)).$$
#
# A matriz PPMI $[M]_{n \times n}$ é uma matriz quadrada que relaciona uma palavra $w$ e um contexto $c$ ao seu valor PPMI, de tal forma que $M(w, c) = ppmi(w, c)$.

# %%
# Número total de bigramas presente na matriz de frequência
numSkipgrams = wwMatrix.sum()

# Mapeamento das entradas da matriz PPMI
rowsIndex = []
columnsIndex = []
ppmiData = []

# Vetor de frequência total de cada palavra em todos os possíveis contextos
sumWords = np.array(wwMatrix.sum(axis=0)).flatten()

# Vetor de frequência total de cada contexto para todas as possíveis palavras
sumContexts = np.array(wwMatrix.sum(axis=1)).flatten()

for (tokenWord, tokenContext), skipgramCount in skipgrams.items():

    # Frequência de determinada palavra em determinado contexto
    # [#(w,c)]
    freqWordContext = skipgramCount

    # Frequência de determinada palavra em todos os contextos possíveis
    # [#(w)]
    freqWord = sumContexts[tokenWord]
    
    # Frequência de determinado contexto para todas as palavras possíveis
    # [#(c)]
    freqContext = sumWords[tokenContext]

    # Probabilidade de ocorrência de determinada palavra em determinado contexto
    # [P(w,c)]
    probWordContext = freqWordContext / numSkipgrams

    # Probabilidade de ocorrência de determinada palavra individualmente
    # [P(w)]
    probWord = freqWord / numSkipgrams

    # Probabilidade de ocorrência de determinado contexto individualmente
    # [P(c)]
    probContext = freqContext / numSkipgrams

    # Cálculo PPMI (Positive Pointwise Mutual Information)
    # [PPMI = max(0, log( P(w,c)/(P(w)P(c)) ))]
    PPMI = max(np.log2(probWordContext / (probWord * probContext)), 0)

    rowsIndex.append(tokenWord)
    columnsIndex.append(tokenContext)
    ppmiData.append(PPMI)

ppmiMatrix = sparse.csr_matrix((ppmiData, (rowsIndex, columnsIndex)))
ppmiMatrix
# Out:
# <10503x10503 sparse matrix of type '<class 'numpy.float64'>'
# 	with 460155 stored elements in Compressed Sparse Row format>

# %%
# # Número total de bigramas presente na matriz de frequência
# numSkipgrams = wwMatrix.sum()

# # Mapeamento das entradas da matriz PPMI
# rowsIndex = []
# columnsIndex = []
# ppmiData = []
# sppmiData = []

# # Vetor de frequência total de cada palavra em todos os possíveis contextos
# sumWords = np.array(wwMatrix.sum(axis=0)).flatten()

# # Vetor de frequência total de cada contexto para todas as possíveis palavras
# sumContexts = np.array(wwMatrix.sum(axis=1)).flatten()

# #smoothing
# alpha = 0.75
# sumOverWordsAlpha = sumWords**alpha
# sumAllWordsAlpha = np.sum(sumOverWordsAlpha)




# for (tokenWord, tokenContext), skipgramCount in skipgrams.items():

#     # Frequência de determinada palavra em determinado contexto
#     # [#(w,c)]
#     freqWordContext = skipgramCount

#     # Frequência de determinada palavra em todos os contextos possíveis
#     # [#(w)]
#     freqWord = sumContexts[tokenWord]
    
#     # Frequência de determinado contexto para todas as palavras possíveis
#     # [#(c)]
#     freqContext = sumWords[tokenContext]

#     # Probabilidade de ocorrência de determinada palavra em determinado contexto
#     # [P(w,c)]
#     probWordContext = freqWordContext / numSkipgrams

#     # Probabilidade de ocorrência de determinada palavra individualmente
#     # [P(w)]
#     probWord = freqWord / numSkipgrams

#     # Probabilidade de ocorrência de determinado contexto individualmente
#     # [P(c)]
#     probContext = freqContext / numSkipgrams
    
#     nca = sumOverWordsAlpha[tokenContext]
#     Pca = nca/sumAllWordsAlpha

#     # Cálculo PPMI (Positive Pointwise Mutual Information)
#     # [PPMI = max(0, log( P(w,c)/(P(w)P(c)) ))]
#     PPMI = max(np.log2(probWordContext / (probWord * probContext)), 0)
#     SPPMI = max(np.log2(probWordContext/ (probWord * Pca)), 0)

#     rowsIndex.append(tokenWord)
#     columnsIndex.append(tokenContext)
#     ppmiData.append(PPMI)
#     sppmiData.append(SPPMI)

# ppmiMatrix = sparse.csr_matrix((sppmiData, (rowsIndex, columnsIndex)))

# %% [markdown]
# ### 7. Fatoração matricial usando SVD (Singular Value Decomposition)

# %% [markdown]
# A Decomposição por Valor Singular (SVD) é uma maneira possível de fatorarmos a matriz esparça de PPMI, de maneira que possamos deixá-la mais densa. Uma matriz $[M]_{m \times n}$ pode ser fatorada da forma
#
# $$M = U \Sigma V^*$$
#
# onde $[U]_{m \times m}$ é uma matriz unitária, $[\Sigma]_{m \times n}$ é uma matriz retangular diagonal e $[V^*]_{n \times n}$ é uma matriz unitária (dita conjugada transposta de $V$). As entradas diagonais de $\Sigma$ são os ditos valores singulares de $M$, enquanto o espaço-coluna de $U$ e $V$ contém os ditos vetores singulares à esquerda e à direita de $M$, respectivamente.

# %%
from scipy.sparse.linalg import svds as SVD

# Dimensão proposta da matriz de valores singulares produzida pelo SVD
# [Hiperparâmetro]
embeddingSize = 50

U, D, V = SVD(ppmiMatrix, embeddingSize)

# Normalização das matrizes de vetores singulares produzidas pelo SVD
Unorm = U / np.sqrt(np.sum(U*U, axis=1, keepdims=True))
Vnorm = V / np.sqrt(np.sum(V*V, axis=1, keepdims=True))

wordVecs = Unorm

# %% [markdown]
# ### 8. Visualização de palavras similares por similaridade por cosseno

# %% [markdown]
# A similaridade por cosseno é uma métrica de similaridade entre vetores que consiste em comparar o ângulo entre eles. Para dois vetores $u$ e $v$, a similaridade por cosseno pode ser descrita pela relação
#
# $$cos(\theta) = \dfrac{u \cdot v}{||u||\ ||v||} = \dfrac{\sum_{i=1}^n u_i v_i}{\sqrt{\sum_{i=1}^n u_i^{\ 2}}\ \sqrt{\sum_{i=1}^n v_i^{\ 2}}}$$
#
# de tal forma que $\theta$ descreve o ângulo entre esses vetores e $u \cdot v$ é o produto escalar entre eles. Essa métrica de similiadade pode ser utilizada, em palavras vetorizadas, para medir o índice de relação entre uma palavra e um contexto.

# %%
from sklearn.metrics.pairwise import cosine_similarity

# Cálculo dos 10 contextos mais similares a dada palavra utilizando a matriz de Word Embedding
def wordsSimilarity(word, matrix, n):
    wordIndex = token2index[word]

    # Resgate do vetor representante de determinada palavra
    if isinstance(matrix, sparse.csr_matrix):
        wordVec = matrix.getrow(wordIndex)
    else:
        wordVec = matrix[wordIndex:wordIndex+1, :]

    # Cálculo da similidade (similaridade de vetores por cosseno)
    similarity = cosine_similarity(matrix, wordVec).flatten()
    sortedIndexes = np.argsort(-similarity)

    # Retorno dos n contextos mais similares a dada palavra
    similarityContextScores = [(index2token[sortedIndex], similarity[sortedIndex]) 
                                for sortedIndex in sortedIndexes[:n+1] 
                                if index2token[sortedIndex] != word]

    return similarityContextScores

def wordSimilarityReport(word, matrix, n=5):
    print(f'\'{word}\'\t Frequência total: {unigrams[word]}', end='\n\t')

    similarityContextScores = wordsSimilarity(word, matrix, n)
    for context, similarity in similarityContextScores:
        print(f'(\'{context}\', {similarity})', end='\t')

# %%
examples = ['facebook', 'twitter', 'instagram', 'messenger', 'hack', 'security', 
          'deep', 'encryption', 'command', 'venture' , 'bitcoin', 'github', 'opensource',
          'linux', 'microsoft', 'tensorflow', 'whatsapp', 'kernel', 'bill', 'elon', 'silicon', 'course',
           'startup', 'blog']
for word in examples:
    wordSimilarityReport(word, wordVecs)
    print('\n'+'---'*20)
# Out:
# 'facebook'	 Frequência total: 2853
# 	('messenger', 0.720751118982211)	('twitter', 0.6842787707680815)	('snapchat', 0.6418796222458363)	('whatsapp', 0.6410669126945807)	('messaging', 0.6234713119193795)
# ------------------------------------------------------------
# 'twitter'	 Frequência total: 1641
# 	('facebook', 0.6842787707680814)	('instagram', 0.6831328132312583)	('linkedin', 0.5858079091725139)	('account', 0.49949205297874283)	('bot', 0.48827841349659457)
# ------------------------------------------------------------
# 'instagram'	 Frequência total: 391
# 	('twitter', 0.6831328132312586)	('facebook', 0.6113646876407349)	('snapchat', 0.6099441484819004)	('stories', 0.5313702489719168)	('photos', 0.5046790641016634)
# ------------------------------------------------------------
# 'messenger'	 Frequência total: 374
# 	('chat', 0.8727600883148274)	('messaging', 0.8390685608952657)	('whatsapp', 0.7805619280282985)	('bot', 0.7715897163695413)	('bots', 0.7313242617882867)
# ------------------------------------------------------------
# 'hack'	 Frequência total: 881
# 	('hackers', 0.7489090801585123)	('hacking', 0.7438164019295066)	('hacked', 0.7292230701412058)	('attack', 0.6051990524712034)	('malware', 0.5013415055530921)
# ------------------------------------------------------------
# 'security'	 Frequência total: 2425
# 	('attacks', 0.5094220995367436)	('vulnerability', 0.46124546894669677)	('management', 0.4512859821351515)	('cyber', 0.4403679353057082)	('policy', 0.42047435259245847)
# ------------------------------------------------------------
# 'deep'	 Frequência total: 1375
# 	('learning', 0.9274560889206711)	('neural', 0.9036879638215236)	('tensorflow', 0.8390580079917871)	('networks', 0.8370827862509577)	('machine', 0.8329409842738034)
# ------------------------------------------------------------
# 'encryption'	 Frequência total: 967
# 	('crypto', 0.6726910861927115)	('surveillance', 0.5705888917312701)	('snowden', 0.5292468936769262)	('bill', 0.5149522263089701)	('calls', 0.5067663115200758)
# ------------------------------------------------------------
# 'command'	 Frequência total: 593
# 	('line', 0.9241424005983117)	('cli', 0.9069246935658224)	('shell', 0.7289177654170997)	('tool', 0.662684536588583)	('files', 0.6483855350515776)
# ------------------------------------------------------------
# 'venture'	 Frequência total: 393
# 	('capital', 0.9242019391842802)	('funding', 0.8056599731112807)	('vc', 0.777745445569426)	('fund', 0.7701937019970532)	('investors', 0.6424514836475728)
# ------------------------------------------------------------
# 'bitcoin'	 Frequência total: 1427
# 	('blockchain', 0.8071992025776656)	('ethereum', 0.6920353010601039)	('bank', 0.6735981494969088)	('banks', 0.5346509632416335)	('financial', 0.4879412653627038)
# ------------------------------------------------------------
# 'github'	 Frequência total: 1419
# 	('git', 0.6177637879406201)	('extension', 0.6095314399294594)	('projects', 0.558219166921224)	('npm', 0.5228625611980277)	('pages', 0.505397515070807)
# ------------------------------------------------------------
# 'opensource'	 Frequência total: 706
# 	('source', 0.8058131716992747)	('open', 0.6774015525820622)	('introducing', 0.5239940023795376)	('platform', 0.5117947321704084)	('analytics', 0.48047460212109894)
# ------------------------------------------------------------
# 'linux'	 Frequência total: 1803
# 	('windows', 0.7900644045266949)	('ubuntu', 0.745941655807657)	('os', 0.6843644268326579)	('mac', 0.6584241866267168)	('kernel', 0.655055622420463)
# ------------------------------------------------------------
# 'microsoft'	 Frequência total: 1856
# 	('ibm', 0.6849302425519515)	('oracle', 0.5823782845568086)	('core', 0.5719459331153443)	('available', 0.5713170082243026)	('studio', 0.5662089305735055)
# ------------------------------------------------------------
# 'tensorflow'	 Frequência total: 302
# 	('deep', 0.839058007991787)	('learning', 0.7964982272709265)	('neural', 0.7656009419242988)	('machine', 0.7321647261649298)	('networks', 0.6707167262790769)
# ------------------------------------------------------------
# 'whatsapp'	 Frequência total: 323
# 	('messenger', 0.7805619280282985)	('messaging', 0.7506339509638571)	('chat', 0.7012102309599874)	('facebook', 0.6410669126945807)	('bots', 0.6016612437587493)
# ------------------------------------------------------------
# 'kernel'	 Frequência total: 359
# 	('linux', 0.655055622420463)	('windows', 0.5060198213634075)	('vulnerability', 0.5060159767963646)	('memory', 0.5053605353762207)	('pdf', 0.49757169155105596)
# ------------------------------------------------------------
# 'bill'	 Frequência total: 745
# 	('government', 0.6143943328994347)	('surveillance', 0.5806164519059825)	('california', 0.5721671937694476)	('uk', 0.5448370016555355)	('law', 0.5302604475706344)
# ------------------------------------------------------------
# 'elon'	 Frequência total: 486
# 	('musk', 0.9897363975054949)	('tesla', 0.7168349912861794)	('electric', 0.5976609714702239)	('spacex', 0.5943424060437581)	('model', 0.5903840208473905)
# ------------------------------------------------------------
# 'silicon'	 Frequência total: 1382
# 	('valley', 0.9778028159188895)	('tech', 0.573458096708994)	('venture', 0.4793454408124048)	('diversity', 0.47692769252905903)	('capital', 0.44396823832503185)
# ------------------------------------------------------------
# 'course'	 Frequência total: 416
# 	('tutorial', 0.6005293572621107)	('introduction', 0.5984021250684162)	('quick', 0.5318355402703233)	('complete', 0.5193366894944751)	('fun', 0.5055547286347881)
# ------------------------------------------------------------
# 'startup'	 Frequência total: 3849
# 	('founders', 0.7975542423657839)	('startups', 0.6917247310911027)	('fund', 0.6206986245628773)	('entrepreneurs', 0.603812887618877)	('yc', 0.5717578373738026)
# ------------------------------------------------------------
# 'blog'	 Frequência total: 590
# 	('post', 0.7225275082707407)	('site', 0.6452629266324947)	('content', 0.6053962110150969)	('wordpress', 0.5907806075404161)	('website', 0.5789042699775031)
# ------------------------------------------------------------

# %% [markdown]
# ### 9. Visualizando as palavras através de um ScatterPlot interativo

# %% [markdown]
# Para que seja possível plotar as palavras é preciso realizar uma redução de dimensionalidade nos dados, uma vez que a dimensão dos vetores de *embedding* é maior do que dois.
#
# Serão testados dois métodos de redução de dimensionalidade:
# * PCA (*Principal Component Analysis*): Promove uma transformação linear ortogonal nos dados, projetando-os em uma nova base que preserva o máximo possível da variância dos dados. Dessa forma, ao longo da primeira coordenada (primeira componente) tem-se a maior variância e, analogamente, ao longo da segunda coordenada (segunda componente) tem-se a segunda maior variância.
#
# * t-SNE (*T-distributed Stochastic Neighbor Embedding*): Método estatístico que estabelece uma distribuição de probabilidade para todos os pares de pontos de tal forma que para pontos similares (pontos próximos a partir de uma dada métrica) serão atribuídas uma alta probabilidade, enquanto para pontos dissimilares (pontos distantes) serão atribuídas uma baixa probabilidade. A métrica escolhida será o cosseno.
#
# Após a redução de dimensionalidade será possível plotar as palavras em um espaço euclideano de duas dimensões, em que cada ponto representa uma palavra.

# %%
def createWordVecsDataFrame(reducedWordVecs, token2index):
    # Criando um dicionário para cada palavra e seu respectivo vetor após redução de dimensionalidade
    dictReducedWordVecs = {}
    for word, index in token2index.items():
        dictReducedWordVecs[word] = reducedWordVecs[index]

    # Instanciando o dataframe a partir do dicionario criado acima
    dfWordVecs = pd.DataFrame.from_dict(
        data = dictReducedWordVecs,
        orient = 'index',
        columns = ['x', 'y']
    )
    dfWordVecs['word'] = dfWordVecs.index
    
    return dfWordVecs

# %%
# Configurando a ferramenta interativa com o notebook
from bokeh.plotting import figure, show, output_notebook
from bokeh.models import HoverTool, ColumnDataSource, value

output_notebook()


def interativePlot(df, title = None, xlabel = None, ylabel = None):
    # Instancia uma ColumnDAtaSource do Bokeh usando o dataframe
    data = ColumnDataSource(df)

    # Cria o plot e configura:
    # título, dimensões e ferramentas interativas
    plot = figure(
        title= title,
        plot_width=800,
        plot_height=800,
        tools=(
            'pan, wheel_zoom, box_zoom,'
            'box_select, reset',
            HoverTool(tooltips = '@word')
            ),
        active_scroll='wheel_zoom',
        x_axis_label = xlabel,
        y_axis_label = ylabel
        )

    # Desenha os circulos representado as palavras
    plot.circle(
        'x',
        'y',
        source=data,
        color='blue',
        line_alpha=0.2,
        fill_alpha=0.1,
        size=10,
        hover_line_color='black'
        )

    # Configuração de outros detalhes visuais
    plot.xaxis.visible = False
    plot.yaxis.visible = False
    plot.grid.grid_line_color = None
    plot.outline_line_color = None


    show(plot);
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>

# %%
from sklearn.decomposition import PCA

# Realizando redução de dimensão com PCA
pca = PCA(n_components = 2)
reducedWordVecs = pca.fit_transform(wordVecs)
print(pca.explained_variance_)

dfWordVecs = createWordVecsDataFrame(reducedWordVecs, token2index)
interativePlot(dfWordVecs, title = 'Word Vecs (PCA)')
# Out:
# [0.90834483 0.00250226]
#   <div class="bk-root" id="a933cba1-5eb2-4d49-a2b2-848c0180a1f7" data-root-id="1005"></div>

# %%
from sklearn.manifold import TSNE
tsne = TSNE(metric = 'cosine')
reducedWordVecs = tsne.fit_transform(wordVecs)

dfWordVecs = createWordVecsDataFrame(reducedWordVecs, token2index)
interativePlot(dfWordVecs, title = 'Word Vecs (TSNE)')
# Out:
#   <div class="bk-root" id="541875f5-d7fd-4e8f-873c-23fb8e2f9164" data-root-id="1113"></div>

# %% [markdown]
# ### 10. Visualização a partir de um agrupamento hierárquico das palavras

# %% [markdown]
# Também podemos visualizar o resultado através de um agrupamento hierárquico de um conjunto de palavras.
#
# A hierarquia será obtida através do agrupamento aglomerativo, no qual, inicialmente, cada ponto possuirá seu próprio *cluster* e cada par de *clusters* próximos serão agrupados a medida que a hierarquia aumenta.
#
# Sejam dois agrupamentos $S$ e $T$, a distância entre os cluster será dada por $d(S,T)$. Quando $S$ e $T$ são agrupados em um único cluster $U$, então $S$ e $T$ serão removidos e substituídos por $U$. Ao final do algoritmo restará um único cluster, o qual será a raiz da hierarquia.
#
# Seja o cluster $U$ de $dim(U) = n$ formado pelos pontos $\{u_{0}, u_{1}, ..., u_{i}, ..., u_{n-1}\}$ e seja $V$ um outro *cluster* $V$ de $dim(V) = m$ formado pelos pontos $\{v_{0}, v_{1}, ..., v_{j}, ..., v_{m-1}\}$, a distância entre os clusters $U$ e $V$ será dada por:
#
# $$d(U,V) = \sum_{i,j}^{n,m} \dfrac{d(u_{i}, v_{j})}{n*m}$$
#
# em que,
#
# $$d(u_{i}, v_{j}) = \dfrac{u \cdot v}{||u||\ ||v||}$$
#
# Ou seja, a distância entre os pontos de um cluster será dada pela métrica de distância cosseno e a distância entre os cluster será dada pela média das distâncias entre os pontos de um par de *clusters*. Os pares de clusters a serem agrupados serão aqueles de menor distância.
#
# Em seguida, os agrupamentos hierárquicos serão visualizado através de um dendograma.

# %%
# Cria um conjunto de palavras considerando as de referência juntamente com as suas n mais similares
def sampleWords(referenceWords, wordVecs, n = 5):
    sample = set()
    for word in referenceWords:
        sample.add(word)
        similarityContextScores = wordsSimilarity(word, wordVecs, n)
        for context, _ in similarityContextScores:
            sample.add(context)
            
    return sample

# %%
# Escolhe as palavras que serão usadas como referência para obter uma amostra
referenceWords = examples

sample = sampleWords(referenceWords, wordVecs)

# Obtem os respectivos Word Embeddings
embeddings = [wordVecs[token2index[word]] for word in sample]

# %%
# # Escolhe as palavras que serão usadas como referência para obter uma amostra
# referenceWords = [
#     'defunto', 'brás', 'romance', 'coimbra', 'flagelo', 'alegria', 'shakespeare', 'homem',
#     'filósofo', 'festa', 'olho', 'ontem', 'guerra', 'faculdade'
# ]

# sample = sampleWords(referenceWords, wordVecs)

# # Obtem os respectivos Word Embeddings
# embeddings = [wordVecs[token2index[word]] for word in sample]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
def plotDendogram(words, embeddings, title = None, xlabel = None, ylabel = None, figsize = (25,5)):
    plt.figure(figsize = figsize)
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    
    # clustering do tipo aglomerativo, usando como critério de agrupamento 
    # a média da distância entre os pontos de um par de cluster, usando o cosseno 
    # como métrica de distância entre os pontos
    link = linkage(embeddings, method = 'average', metric = 'cosine')
    
    dendrogram(
        link,
        labels = words,
        leaf_rotation=90.,  
        leaf_font_size=10.,  
        orientation='top',
    )
    
    plt.show()

# %%
plotDendogram(list(sample), embeddings, title = 'Dendograma Agrupamento Hierárquico', 
              ylabel = 'distância', xlabel = 'token')

# %%
len(token2index)
# Out:
# 972
